# %% [markdown]
# # Deep Learning
# ## Assignment 5
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
# import ipdb
from IPython.core.debugger import Tracer

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
#   Tracer()()
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'anarchism', 'term', 'a', 'originated', 'of', 'as', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.054968
# Nearest to but: conformation, watered, respectfully, prot, katz, topaz, gamal, soundtrack,
# Nearest to from: documentation, unfairness, lorne, jadwiga, weasels, spacesuit, gambling, acorns,
# Nearest to they: kulak, covalently, germination, rawlings, circumnavigated, herbalists, goods, wished,
# Nearest to during: letterbox, lollards, gtpases, charted, cuttlefish, dorm, election, contains,
# Nearest to one: humanities, acapulco, fats, veeck, sober, motor, planetfall, obstructions,
# Nearest to if: musicianship, ifr, totoro, cours, swarm, bug, moines, introns,
# Nearest to five: roofs, adjacency, sunspot, executes, kets, equations, forward, app,
# Nearest to into: len, imbalances, bcd, gao, minimalism, arena, wigan, serfdom,
# Nearest to united: excavate, faa, berkeley, ula, eretz, elm, slots, vehement,
# Nearest to and: cigarette, dives, christopher, commercial, stood, blacklist, approximating, fruitless,
# Nearest to about: manga, ljubljana, milo, entropic, assassinate, slimmer, textbooks, baguirmi,
# Nearest to for: strassburg, accelerators, blacki, pvp, swelled, kwashiorkor, investigates, maximally,
# Nearest to not: cathy, instrumental, kasner, remo, conformations, suharto, horizons, told,
# Nearest to their: coalesced, significance, receding, leaking, keynesian, organum, shorthair, jumper,
# Nearest to has: sylvia, afrika, connors, athletic, achieved, francium, mandela, mesoplodon,
# Nearest to who: deals, warlords, atil, unpredictable, medically, rabinowitz, tropic, hbox,
# Average loss at step 2000: 4.371270
# Average loss at step 4000: 3.864614
# Average loss at step 6000: 3.788398
# Average loss at step 8000: 3.689717
# Average loss at step 10000: 3.613227
# Nearest to but: topaz, tuberculosis, alive, straightforwardly, is, he, they, minurso,
# Nearest to from: in, between, into, by, headshot, colfax, against, documentation,
# Nearest to they: he, germination, not, it, there, kulak, that, navarro,
# Nearest to during: in, while, letterbox, charted, thelma, dorm, contains, became,
# Nearest to one: three, two, six, seven, four, eight, five, nizam,
# Nearest to if: spectrum, includes, pka, ferranti, swarm, tractors, downing, totoro,
# Nearest to five: eight, six, three, four, seven, nine, two, zero,
# Nearest to into: imbalances, to, arena, from, relative, wigan, on, joyful,
# Nearest to united: ula, slots, vehement, berkeley, ergot, oceanographic, eastward, twenty,
# Nearest to and: or, aeolian, who, bamboo, s, in, cliffordadams, dignitaries,
# Nearest to about: ambergris, slimmer, ljubljana, zola, slams, matra, entire, clairvaux,
# Nearest to for: stockpiling, dialysis, hanging, abkhazia, misrepresenting, bjelke, sticky, devoured,
# Nearest to not: they, it, structures, observe, mei, also, generally, horizons,
# Nearest to their: his, its, brevity, each, martinique, this, receding, peerage,
# Nearest to has: had, is, have, was, became, breastplate, ethically, relies,
# Nearest to who: he, and, geared, ural, which, rabinowitz, touma, cost,
# Average loss at step 12000: 3.601504
# Average loss at step 14000: 3.577035
# Average loss at step 16000: 3.411753
# Average loss at step 18000: 3.458403
# Average loss at step 20000: 3.536260
# Nearest to but: however, that, which, derby, is, and, though, did,
# Nearest to from: in, between, into, after, marketplace, against, mouthpiece, at,
# Nearest to they: he, there, we, not, who, you, it, snorri,
# Nearest to during: in, while, letterbox, at, attaining, thelma, where, analyst,
# Nearest to one: three, two, four, six, eight, seven, five, nine,
# Nearest to if: when, spectrum, though, will, where, pka, would, includes,
# Nearest to five: six, three, four, seven, eight, zero, two, nine,
# Nearest to into: from, through, between, with, up, after, arena, tis,
# Nearest to united: ula, slots, ergot, vehement, oceanographic, berkeley, elm, lighthouse,
# Nearest to and: or, in, but, of, medical, for, kar, which,
# Nearest to about: ljubljana, novak, slimmer, zola, matra, slams, icp, sothoth,
# Nearest to for: by, of, with, in, and, bjelke, on, stockpiling,
# Nearest to not: they, mei, also, it, usually, to, there, accommodated,
# Nearest to their: his, its, the, each, her, adrien, brevity, receding,
# Nearest to has: had, have, is, was, breastplate, toxins, crystals, became,
# Nearest to who: he, which, often, also, they, impressions, rabinowitz, touma,
# Average loss at step 22000: 3.505408
# Average loss at step 24000: 3.489689
# Average loss at step 26000: 3.479023
# Average loss at step 28000: 3.479445
# Average loss at step 30000: 3.505310
# Nearest to but: however, and, though, which, that, while, although, when,
# Nearest to from: into, between, in, after, against, towards, of, headshot,
# Nearest to they: there, we, he, who, it, you, not, these,
# Nearest to during: after, in, at, while, through, when, nicolson, before,
# Nearest to one: two, seven, four, three, eight, six, five, nine,
# Nearest to if: when, though, where, will, would, pka, linemen, is,
# Nearest to five: four, eight, seven, three, six, nine, two, zero,
# Nearest to into: from, through, between, tis, off, restart, theobromine, over,
# Nearest to united: ula, slots, oceanographic, lighthouse, vehement, ergot, perspective, braille,
# Nearest to and: or, but, in, who, educate, of, cker, geraldine,
# Nearest to about: zola, slimmer, emma, back, ljubljana, matra, entire, within,
# Nearest to for: when, umbra, with, of, jamiroquai, monet, patterned, brontosaurus,
# Nearest to not: they, it, there, now, mei, shot, also, usually,
# Nearest to their: its, his, the, her, each, brevity, adrien, these,
# Nearest to has: had, have, is, was, toxins, breastplate, recently, blogging,
# Nearest to who: he, they, which, often, and, impressions, she, gx,
# Average loss at step 32000: 3.497266
# Average loss at step 34000: 3.495639
# Average loss at step 36000: 3.451384
# Average loss at step 38000: 3.305305
# Average loss at step 40000: 3.427706
# Nearest to but: however, though, and, although, while, when, it, quotations,
# Nearest to from: into, after, between, towards, in, through, vortigern, by,
# Nearest to they: we, there, he, you, it, these, not, she,
# Nearest to during: after, at, in, before, through, until, while, between,
# Nearest to one: seven, six, eight, five, two, four, three, nine,
# Nearest to if: when, where, though, linemen, weighty, balm, can, is,
# Nearest to five: seven, six, three, four, eight, zero, two, nine,
# Nearest to into: from, through, off, between, gain, remove, sistine, theobromine,
# Nearest to united: ula, lighthouse, slots, oceanographic, perspective, vehement, mussorgsky, elm,
# Nearest to and: or, but, yucatan, solvent, mesopotamian, d, xxxviii, to,
# Nearest to about: slimmer, matra, ljubljana, zola, emma, assumptions, novak, deduce,
# Nearest to for: after, when, of, in, sigma, umbra, within, by,
# Nearest to not: they, also, usually, shot, it, still, stand, mei,
# Nearest to their: its, his, her, the, brevity, antiochian, some, each,
# Nearest to has: had, have, was, is, blogging, toxins, breastplate, substantiate,
# Nearest to who: he, which, often, impressions, they, aeolian, she, gx,
# Average loss at step 42000: 3.441254
# Average loss at step 44000: 3.453700
# Average loss at step 46000: 3.448882
# Average loss at step 48000: 3.358412
# Average loss at step 50000: 3.380169
# Nearest to but: however, though, although, when, while, and, avro, until,
# Nearest to from: into, in, towards, marketplace, during, between, through, pyle,
# Nearest to they: he, we, there, she, you, it, these, not,
# Nearest to during: after, in, at, when, however, before, while, since,
# Nearest to one: two, six, eight, four, seven, three, five, nine,
# Nearest to if: when, though, where, currying, linemen, martov, posthumus, runtime,
# Nearest to five: four, six, seven, eight, three, zero, two, nine,
# Nearest to into: through, from, off, on, gain, theobromine, between, sistine,
# Nearest to united: ula, slots, lighthouse, perspective, vehement, elm, socializing, mussorgsky,
# Nearest to and: or, but, including, while, of, however, than, like,
# Nearest to about: slimmer, matra, zola, over, on, geddes, emma, deduce,
# Nearest to for: against, unexplored, sigma, ser, including, propensity, evaporating, after,
# Nearest to not: usually, now, still, they, somewhat, never, generally, it,
# Nearest to their: its, his, her, the, some, both, antiochian, these,
# Nearest to has: had, have, was, is, nico, substantiate, stonework, during,
# Nearest to who: he, which, she, teutoburg, also, agonist, impressions, they,
# Average loss at step 52000: 3.434011
# Average loss at step 54000: 3.428335
# Average loss at step 56000: 3.441668
# Average loss at step 58000: 3.397841
# Average loss at step 60000: 3.397154
# Nearest to but: however, and, though, although, than, when, avro, see,
# Nearest to from: into, through, in, between, under, since, towards, subsidized,
# Nearest to they: we, there, you, he, she, i, these, it,
# Nearest to during: after, in, before, although, when, at, following, since,
# Nearest to one: two, six, four, eight, seven, five, three, nine,
# Nearest to if: when, though, where, is, then, because, linemen, so,
# Nearest to five: six, four, three, seven, eight, zero, nine, two,
# Nearest to into: through, from, over, theobromine, across, off, sistine, in,
# Nearest to united: emigrant, lighthouse, ula, socializing, vehement, perspective, following, mussorgsky,
# Nearest to and: or, but, including, than, through, ageing, from, devotional,
# Nearest to about: over, slimmer, on, deduce, churning, zola, novak, adolescent,
# Nearest to for: including, of, to, when, in, sigma, regional, phallic,
# Nearest to not: now, usually, never, still, to, almost, emulator, they,
# Nearest to their: its, his, her, the, your, our, some, rosamund,
# Nearest to has: had, have, was, is, having, substantiate, contacting, travers,
# Nearest to who: he, which, gx, agonist, teutoburg, impressions, pensacola, aeolian,
# Average loss at step 62000: 3.242645
# Average loss at step 64000: 3.255864
# Average loss at step 66000: 3.407333
# Average loss at step 68000: 3.396104
# Average loss at step 70000: 3.358495
# Nearest to but: however, although, than, though, and, which, while, see,
# Nearest to from: into, through, between, towards, marketplace, across, headshot, in,
# Nearest to they: we, there, he, you, it, she, soon, these,
# Nearest to during: after, before, in, welterweight, until, since, following, at,
# Nearest to one: two, six, seven, four, eight, five, three, nine,
# Nearest to if: when, though, where, because, runtime, although, while, so,
# Nearest to five: four, six, three, seven, eight, zero, nine, two,
# Nearest to into: from, through, off, theobromine, across, sistine, meconium, whenever,
# Nearest to united: lighthouse, mussorgsky, vehement, temple, slots, socializing, same, ula,
# Nearest to and: or, but, including, like, through, residential, include, which,
# Nearest to about: over, evasive, slimmer, around, zola, regarding, deduce, adolescent,
# Nearest to for: including, against, in, sigma, of, unexplored, polypeptides, conscious,
# Nearest to not: now, usually, never, still, generally, mei, almost, probably,
# Nearest to their: its, his, her, the, your, our, antiochian, these,
# Nearest to has: had, have, is, was, since, winnipeg, anima, contains,
# Nearest to who: he, rassemblement, which, teutoburg, gx, multiculturalism, nokia, agonist,
# Average loss at step 72000: 3.369628
# Average loss at step 74000: 3.349568
# Average loss at step 76000: 3.310286
# Average loss at step 78000: 3.353216
# Average loss at step 80000: 3.379319
# Nearest to but: however, although, while, than, and, though, that, which,
# Nearest to from: through, into, between, across, towards, in, after, marketplace,
# Nearest to they: we, there, he, you, she, it, soon, these,
# Nearest to during: after, before, in, when, at, throughout, welterweight, until,
# Nearest to one: seven, six, two, eight, three, four, five, nine,
# Nearest to if: when, though, since, where, before, because, runtime, so,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to into: through, from, off, across, pakistani, tis, between, over,
# Nearest to united: same, lighthouse, licensing, vehement, mussorgsky, elm, socializing, akkadian,
# Nearest to and: or, but, including, while, cray, docklands, tuamotu, marius,
# Nearest to about: over, evasive, slimmer, regarding, churning, loach, placement, deduce,
# Nearest to for: including, against, although, while, beacons, bandar, if, when,
# Nearest to not: now, still, never, generally, usually, they, often, almost,
# Nearest to their: its, his, her, your, our, the, antiochian, my,
# Nearest to has: had, have, is, was, since, having, colouring, winnipeg,
# Nearest to who: he, which, often, still, agonist, gx, teutoburg, slums,
# Average loss at step 82000: 3.410957
# Average loss at step 84000: 3.406681
# Average loss at step 86000: 3.394868
# Average loss at step 88000: 3.353889
# Average loss at step 90000: 3.369507
# Nearest to but: however, although, and, while, though, that, which, she,
# Nearest to from: through, into, towards, across, between, musics, subjecting, in,
# Nearest to they: we, he, there, she, it, you, soon, these,
# Nearest to during: after, before, in, until, when, throughout, at, through,
# Nearest to one: two, seven, four, eight, six, three, five, nine,
# Nearest to if: when, though, since, where, before, vibrate, because, mol,
# Nearest to five: four, seven, eight, three, six, nine, zero, two,
# Nearest to into: through, from, across, around, off, meconium, tis, between,
# Nearest to united: same, lighthouse, licensing, constitution, mussorgsky, socializing, vehement, emigrant,
# Nearest to and: or, but, ageing, while, staggered, including, however, which,
# Nearest to about: evasive, regarding, placement, over, marr, eutelsat, adolescent, amplitudes,
# Nearest to for: after, against, unexplored, of, including, when, while, sassanian,
# Nearest to not: still, now, also, almost, therefore, only, they, rarely,
# Nearest to their: his, its, her, your, our, whose, the, torquato,
# Nearest to has: had, have, is, was, since, having, nico, colouring,
# Nearest to who: he, often, which, but, impressions, grendel, cliffordadams, agonist,
# Average loss at step 92000: 3.397254
# Average loss at step 94000: 3.254819
# Average loss at step 96000: 3.359857
# Average loss at step 98000: 3.244047
# Average loss at step 100000: 3.353399
# Nearest to but: however, although, and, while, though, vultures, which, that,
# Nearest to from: into, through, in, towards, across, musics, subjecting, between,
# Nearest to they: we, he, there, you, she, it, soon, these,
# Nearest to during: after, in, before, throughout, through, until, despite, at,
# Nearest to one: two, four, seven, five, eight, six, three, nine,
# Nearest to if: when, though, where, since, before, while, therefore, although,
# Nearest to five: four, six, seven, eight, three, zero, nine, two,
# Nearest to into: through, from, within, off, across, meconium, tis, around,
# Nearest to united: same, lighthouse, licensing, constitution, following, emigrant, socializing, caribbean,
# Nearest to and: or, but, however, while, who, although, including, than,
# Nearest to about: evasive, regarding, around, on, placement, slimmer, nashwaak, amplitudes,
# Nearest to for: after, when, including, against, beacons, before, despite, without,
# Nearest to not: never, almost, now, still, usually, they, therefore, rarely,
# Nearest to their: its, his, her, your, the, our, whose, torquato,
# Nearest to has: had, have, is, was, since, having, nico, mononoke,
# Nearest to who: he, often, and, which, also, dear, generally, that,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# Noise-contrastive estimation (NCE)

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  nce_weights  = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],stddev=1.0 / math.sqrt(embedding_size)))
  nce_biases  = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.nce_loss(weights=nce_weights, 
                   biases=nce_biases, 
                   inputs=embed,                               
                   labels=train_labels, 
                   num_sampled=num_sampled, 
                   num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 281.435730
# Nearest to often: traditionalists, her, cetaceans, forman, puddle, fred, hoplite, soma,
# Nearest to UNK: ramones, luisa, cranmer, kamal, spada, typhoon, cgpm, augustan,
# Nearest to were: fiercest, thermodynamics, jitsu, latham, bernstein, contours, pournelle, milliardo,
# Nearest to called: shem, muddy, dionysus, alloying, dijkstra, unfashionable, geneva, yttrium,
# Nearest to these: jena, neglects, fraud, ada, chinook, graphical, labyrinths, presenting,
# Nearest to at: tris, conditioned, tenji, punjabi, gallic, tortured, scriptores, jo,
# Nearest to is: alteration, dressed, fairgrounds, impotent, provides, pel, executing, superclusters,
# Nearest to state: pay, cueing, biometric, mlm, nee, andries, deity, filesystem,
# Nearest to such: anniversary, peach, classics, wat, descended, writeups, gravity, soga,
# Nearest to he: davenport, ascii, teddy, godfrey, laurie, altars, dagesh, jealous,
# Nearest to between: unlimited, nicosia, viridian, unaltered, hummer, kaua, janus, retribution,
# Nearest to united: shou, diger, destroyed, magnifying, drachma, ruppert, qd, frameworks,
# Nearest to can: impervious, purdue, superiority, raeder, converter, cois, autocorrelation, komodoensis,
# Nearest to may: kinder, ctor, questioned, babel, hayling, perilous, affecting, lamarckian,
# Nearest to over: tain, summers, piter, confusingly, cerebrum, isc, echolocation, ideograms,
# Nearest to from: boil, hitters, aggressive, ph, brush, ugandan, cushing, baguirmi,
# Average loss at step 2000: 113.727515
# Average loss at step 4000: 52.851425
# Average loss at step 6000: 33.094473
# Average loss at step 8000: 23.505764
# Average loss at step 10000: 17.958140
# Nearest to often: her, ads, fred, spurred, UNK, supporter, the, share,
# Nearest to UNK: and, gland, gollancz, one, austin, the, reginae, mathbf,
# Nearest to were: has, are, is, altruist, austin, aeneas, gb, psi,
# Nearest to called: shem, dionysus, UNK, power, similarly, communication, abraham, stem,
# Nearest to these: vs, mathbf, austin, sands, jena, hinder, requires, chinese,
# Nearest to at: in, of, austin, and, aberdeen, on, pacific, jo,
# Nearest to is: was, are, has, in, and, austin, were, UNK,
# Nearest to state: pay, deity, august, basic, mathbf, transportation, autistic, analogue,
# Nearest to such: anniversary, classics, aa, altenberg, descended, algal, career, aeneas,
# Nearest to he: and, rebel, aki, stressed, infect, it, sarcophagus, ascii,
# Nearest to between: unlimited, properties, algebraic, institutions, populations, roland, soviets, cl,
# Nearest to united: als, destroyed, unlike, quattro, mourned, sanskrit, approval, gb,
# Nearest to can: sir, to, converter, austin, bed, phi, cl, exists,
# Nearest to may: gland, version, questioned, eels, analogue, begin, gb, affecting,
# Nearest to over: legal, portuguese, volunteers, summers, rfcs, crossroads, separate, ancestors,
# Nearest to from: in, for, of, and, grandparents, analogue, combination, sigma,
# Average loss at step 12000: 13.897062
# Average loss at step 14000: 11.836499
# Average loss at step 16000: 9.920086
# Average loss at step 18000: 8.601626
# Average loss at step 20000: 7.782349
# Nearest to often: her, spurred, who, agouti, supporter, ads, which, fred,
# Nearest to UNK: agouti, gland, dasyprocta, phi, and, reginae, gollancz, victoriae,
# Nearest to were: are, is, was, has, and, altruist, have, austin,
# Nearest to called: shem, dionysus, geneva, UNK, muddy, inducted, bodybuilder, similarly,
# Nearest to these: the, many, some, hinder, vs, bats, mathbf, proportional,
# Nearest to at: in, and, on, austin, of, from, by, agouti,
# Nearest to is: was, are, has, in, were, by, agouti, although,
# Nearest to state: pay, deity, analogue, mathbf, basic, august, peptide, informally,
# Nearest to such: classics, anniversary, sigismund, aa, subshell, altenberg, descended, and,
# Nearest to he: it, they, stressed, and, she, infect, amaranth, who,
# Nearest to between: in, unlimited, five, retribution, with, after, and, nine,
# Nearest to united: unlike, als, quattro, destroyed, sanskrit, mourned, approval, relativity,
# Nearest to can: to, sir, purdue, bed, may, wiltshire, converter, functions,
# Nearest to may: eight, gland, eels, questioned, version, since, would, affecting,
# Nearest to over: dasyprocta, chromosomes, legal, and, crossroads, separate, nine, athens,
# Nearest to from: in, for, by, and, at, of, five, on,
# Average loss at step 22000: 7.317593
# Average loss at step 24000: 7.019747
# Average loss at step 26000: 6.690993
# Average loss at step 28000: 6.230296
# Average loss at step 30000: 6.178528
# Nearest to often: who, also, UNK, agouti, her, spurred, which, supporter,
# Nearest to UNK: agouti, trinomial, gland, gollancz, dasyprocta, vdash, phi, reuptake,
# Nearest to were: are, is, was, have, has, by, copernicus, altruist,
# Nearest to called: shem, thinkpad, dionysus, geneva, UNK, and, inducted, meister,
# Nearest to these: many, some, the, hinder, proportional, bats, csi, vs,
# Nearest to at: in, and, from, on, austin, with, agouti, by,
# Nearest to is: was, are, has, were, agouti, although, as, traits,
# Nearest to state: pay, deity, analogue, informally, basic, della, peptide, successes,
# Nearest to such: classics, anniversary, known, sigismund, subshell, rated, several, voluntary,
# Nearest to he: it, they, she, who, and, never, there, stressed,
# Nearest to between: with, unlimited, in, retribution, after, solzhenitsyn, five, trojans,
# Nearest to united: unlike, als, quattro, destroyed, sanskrit, within, mourned, approval,
# Nearest to can: may, to, will, would, bed, impervious, might, wiltshire,
# Nearest to may: can, would, will, must, could, questioned, eels, eight,
# Nearest to over: acadia, chromosomes, legal, dasyprocta, with, separate, crossroads, athens,
# Nearest to from: in, for, through, by, and, at, of, into,
# Average loss at step 32000: 5.852869
# Average loss at step 34000: 5.884245
# Average loss at step 36000: 5.708301
# Average loss at step 38000: 5.298154
# Average loss at step 40000: 5.451873
# Nearest to often: also, who, which, it, agouti, spurred, sometimes, ambiguous,
# Nearest to UNK: agouti, gland, dasyprocta, vdash, trinomial, phi, albury, reginae,
# Nearest to were: are, was, have, is, has, by, be, being,
# Nearest to called: shem, UNK, and, dionysus, thinkpad, geneva, alloying, mw,
# Nearest to these: many, some, bats, the, hinder, several, which, backus,
# Nearest to at: in, on, from, austin, and, agouti, dasyprocta, chalukyas,
# Nearest to is: was, are, has, were, agouti, although, as, traits,
# Nearest to state: pay, deity, analogue, basic, filesystem, successes, informally, peptide,
# Nearest to such: classics, anniversary, known, many, sigismund, breisgau, rated, voluntary,
# Nearest to he: it, she, they, who, never, there, and, stressed,
# Nearest to between: with, in, unlimited, retribution, five, fabled, amusement, solzhenitsyn,
# Nearest to united: unlike, als, quattro, destroyed, within, sanskrit, mourned, unearthed,
# Nearest to can: may, will, would, to, could, might, bed, impervious,
# Nearest to may: can, would, will, must, could, eels, questioned, zero,
# Nearest to over: acadia, dasyprocta, cerebrum, chromosomes, five, legal, four, athens,
# Nearest to from: in, through, for, into, of, and, analogue, on,
# Average loss at step 42000: 5.292649
# Average loss at step 44000: 5.308848
# Average loss at step 46000: 5.258275
# Average loss at step 48000: 5.019492
# Average loss at step 50000: 5.162179
# Nearest to often: also, which, who, sometimes, it, agouti, now, tibet,
# Nearest to UNK: agouti, trinomial, gland, dasyprocta, reuptake, vdash, reginae, five,
# Nearest to were: are, was, have, is, had, has, be, by,
# Nearest to called: UNK, shem, inducted, dionysus, alloying, thinkpad, geneva, mw,
# Nearest to these: many, some, several, bats, both, the, hinder, which,
# Nearest to at: in, on, austin, agouti, thibetanus, dasyprocta, from, chalukyas,
# Nearest to is: was, are, has, were, although, agouti, be, aba,
# Nearest to state: pay, deity, successes, basic, analogue, filesystem, informally, transportation,
# Nearest to such: known, anniversary, classics, many, well, these, several, classified,
# Nearest to he: it, she, they, who, never, there, beeb, this,
# Nearest to between: with, unlimited, in, retribution, amusement, trojans, fabled, solzhenitsyn,
# Nearest to united: unlike, als, quattro, destroyed, within, sanskrit, unearthed, mourned,
# Nearest to can: may, will, would, could, might, to, must, should,
# Nearest to may: can, would, will, must, could, should, solicitation, eight,
# Nearest to over: chromosomes, cerebrum, acadia, dasyprocta, four, and, legal, three,
# Nearest to from: through, in, into, and, analogue, for, nine, by,
# Average loss at step 52000: 5.157570
# Average loss at step 54000: 5.098205
# Average loss at step 56000: 5.060973
# Average loss at step 58000: 5.110218
# Average loss at step 60000: 4.959552
# Nearest to often: also, sometimes, who, now, which, usually, widely, it,
# Nearest to UNK: michelob, agouti, callithrix, saguinus, microcebus, cebus, trinomial, gland,
# Nearest to were: are, have, was, had, is, be, has, being,
# Nearest to called: marmoset, shem, UNK, michelob, inducted, dionysus, alloying, mw,
# Nearest to these: some, many, several, both, such, bats, all, their,
# Nearest to at: in, austin, on, chalukyas, under, thibetanus, agouti, from,
# Nearest to is: was, are, has, agouti, although, but, solicitation, aba,
# Nearest to state: pay, callithrix, deity, michelob, tamarin, successes, suborders, analogue,
# Nearest to such: known, anniversary, well, many, these, classics, voluntary, gravity,
# Nearest to he: it, she, they, who, never, there, beeb, then,
# Nearest to between: with, in, unlimited, solzhenitsyn, retribution, amusement, billings, trojans,
# Nearest to united: unlike, diger, als, unearthed, quattro, within, mourned, destroyed,
# Nearest to can: may, would, will, could, must, might, cannot, to,
# Nearest to may: can, would, will, must, could, should, solicitation, cannot,
# Nearest to over: cerebrum, chromosomes, acadia, dasyprocta, three, four, five, legal,
# Nearest to from: through, into, in, under, callithrix, analogue, on, by,
# Average loss at step 62000: 4.800729
# Average loss at step 64000: 4.768623
# Average loss at step 66000: 4.991433
# Average loss at step 68000: 4.903784
# Average loss at step 70000: 4.784381
# Nearest to often: also, sometimes, now, usually, who, which, widely, actually,
# Nearest to UNK: michelob, agouti, saguinus, callithrix, cebus, microcebus, dasyprocta, reuptake,
# Nearest to were: are, have, was, had, be, is, while, being,
# Nearest to called: UNK, marmoset, shem, michelob, dionysus, inducted, mw, alloying,
# Nearest to these: some, many, several, such, both, all, which, their,
# Nearest to at: in, agouti, on, austin, chalukyas, thibetanus, anaheim, dasyprocta,
# Nearest to is: was, are, has, although, agouti, be, became, but,
# Nearest to state: pay, callithrix, basic, deity, suborders, michelob, informally, successes,
# Nearest to such: known, these, well, many, anniversary, classics, some, voluntary,
# Nearest to he: it, she, they, who, never, there, beeb, then,
# Nearest to between: with, in, unlimited, nicosia, solzhenitsyn, retribution, billings, amusement,
# Nearest to united: unlike, diger, als, within, unearthed, quattro, mourned, destroyed,
# Nearest to can: may, will, would, could, might, must, cannot, to,
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Nearest to over: chromosomes, four, cerebrum, dasyprocta, acadia, three, around, legal,
# Nearest to from: through, into, in, analogue, by, callithrix, fisk, under,
# Average loss at step 72000: 4.811320
# Average loss at step 74000: 4.772526
# Average loss at step 76000: 4.886450
# Average loss at step 78000: 4.788401
# Average loss at step 80000: 4.813586
# Nearest to often: also, sometimes, usually, now, actually, widely, which, who,
# Nearest to UNK: michelob, cegep, agouti, saguinus, cebus, microcebus, three, callithrix,
# Nearest to were: are, have, was, had, be, is, while, xxxiii,
# Nearest to called: marmoset, shem, alloying, michelob, inducted, dionysus, mw, agouti,
# Nearest to these: some, many, several, all, such, both, various, their,
# Nearest to at: in, on, agouti, during, thibetanus, chalukyas, austin, dasyprocta,
# Nearest to is: was, has, are, although, agouti, be, chamada, were,
# Nearest to state: pay, callithrix, michelob, suborders, tamarin, vec, informally, basic,
# Nearest to such: well, known, these, many, anniversary, classics, some, gravity,
# Nearest to he: it, she, they, who, there, never, beeb, stressed,
# Nearest to between: with, in, unlimited, nicosia, solzhenitsyn, through, retribution, billings,
# Nearest to united: unlike, als, unearthed, diger, within, mourned, destroyed, quattro,
# Nearest to can: may, would, will, could, must, might, cannot, should,
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Nearest to over: chromosomes, dasyprocta, around, four, acadia, cerebrum, three, legal,
# Nearest to from: through, into, in, analogue, under, by, during, callithrix,
# Average loss at step 82000: 4.826907
# Average loss at step 84000: 4.782564
# Average loss at step 86000: 4.742331
# Average loss at step 88000: 4.687810
# Average loss at step 90000: 4.759893
# Nearest to often: sometimes, also, usually, now, commonly, actually, widely, who,
# Nearest to UNK: michelob, callithrix, agouti, saguinus, microcebus, dasyprocta, cegep, iit,
# Nearest to were: are, have, was, had, while, be, is, include,
# Nearest to called: marmoset, shem, and, stained, agouti, michelob, mw, alloying,
# Nearest to these: some, many, several, all, such, both, various, which,
# Nearest to at: in, on, during, under, agouti, thibetanus, dasyprocta, diz,
# Nearest to is: was, has, are, agouti, although, chamada, be, if,
# Nearest to state: pay, suborders, michelob, callithrix, basic, tamarin, leben, informally,
# Nearest to such: well, these, known, many, classics, anniversary, some, classified,
# Nearest to he: it, she, they, there, who, never, beeb, but,
# Nearest to between: with, in, unlimited, through, into, solzhenitsyn, nicosia, six,
# Nearest to united: unlike, als, unearthed, diger, arminians, mourned, quattro, destroyed,
# Nearest to can: may, will, would, could, must, might, cannot, should,
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Nearest to over: chromosomes, around, dasyprocta, when, tain, acadia, legal, cerebrum,
# Nearest to from: through, into, in, under, analogue, callithrix, by, during,
# Average loss at step 92000: 4.700892
# Average loss at step 94000: 4.627228
# Average loss at step 96000: 4.743545
# Average loss at step 98000: 4.617177
# Average loss at step 100000: 4.666999
# Nearest to often: sometimes, usually, also, now, generally, widely, actually, commonly,
# Nearest to UNK: michelob, agouti, callithrix, saguinus, four, cegep, iit, microcebus,
# Nearest to were: are, have, had, was, while, is, include, although,
# Nearest to called: UNK, marmoset, shem, agouti, and, alloying, stained, exiles,
# Nearest to these: some, many, several, all, various, such, both, which,
# Nearest to at: in, on, during, under, from, thibetanus, agouti, dasyprocta,
# Nearest to is: was, has, are, agouti, chamada, became, were, although,
# Nearest to state: pay, suborders, michelob, tamarin, callithrix, informally, transportation, escuela,
# Nearest to such: well, known, these, many, classics, anniversary, some, thz,
# Nearest to he: it, she, they, there, who, never, beeb, this,
# Nearest to between: with, dbm, in, unlimited, through, from, into, retribution,
# Nearest to united: unlike, als, unearthed, diger, arminians, chickens, mourned, destroyed,
# Nearest to can: may, will, would, could, must, might, cannot, should,
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Nearest to over: around, chromosomes, dasyprocta, when, three, tain, acadia, within,
# Nearest to from: through, in, into, under, at, during, analogue, callithrix,

# %% [markdown]
# ## Problem
# An alternative to skip-gram is another Word2Vec model called CBOW (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.

# %%
data_index = 0
def generate_batch_CBOW(batch_size, skip_window):
    # skip window is the amount of words we're looking at from each side of a given word
    # creates a single batch
    global data_index
#     assert skip_window%2==1
 
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
 
    batch = np.ndarray(shape=(batch_size,span-1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    # e.g if skip_window = 2 then span = 5
    # span is the length of the whole frame we are considering for a single word (left + word + right)
    # skip_window is the length of one side
 
    # queue which add and pop at the end
    buffer = collections.deque(maxlen=span)
 
    #get words starting from index 0 to span
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
 
    # num_skips => # of times we select a random word within the span?
    # batch_size (8) and num_skips (2) (4 times)
    # batch_size (8) and num_skips (1) (8 times)
    for i in range(batch_size):
        target = skip_window  # target label at the center of the buffer
        target_to_avoid = [ skip_window ] # we only need to know the words around a given word, not the word itself
 
        # do this num_skips (2 times)
        # do this (1 time)
 
        # add selected target to avoid_list for next time
        col_idx = 0
        for j in range(span):
            if j==span//2:
                continue
            # e.g. i=0, j=0 => 0; i=0,j=1 => 1; i=1,j=0 => 2
            batch[i,col_idx] = buffer[j] # [skip_window] => middle element
            col_idx += 1
        labels[i, 0] = buffer[target]
 
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
 
    assert batch.shape[0]==batch_size and batch.shape[1]== span-1
    return batch, labels

# %%
print('data:', [reverse_dictionary[di] for di in data[:8]])
for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch_CBOW(batch_size=8, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    for b in batch:
        print('    batch:', [reverse_dictionary[bi] for bi in b])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['anarchism', 'as']
#     batch: ['originated', 'a']
#     batch: ['as', 'term']
#     batch: ['a', 'of']
#     batch: ['term', 'abuse']
#     batch: ['of', 'first']
#     batch: ['abuse', 'used']
#     batch: ['first', 'against']
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['anarchism', 'originated', 'a', 'term']
#     batch: ['originated', 'as', 'term', 'of']
#     batch: ['as', 'a', 'of', 'abuse']
#     batch: ['a', 'term', 'abuse', 'first']
#     batch: ['term', 'of', 'first', 'used']
#     batch: ['of', 'abuse', 'used', 'against']
#     batch: ['abuse', 'first', 'against', 'early']
#     batch: ['first', 'used', 'early', 'working']
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
# pick 16 samples from 100
valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
valid_examples = np.append(valid_examples,random.sample(range(1000,1000+valid_window), valid_size//2))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size,2*skip_window])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    # embedding, vector for each word in the vocabulary
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                     stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    # this might efficiently find the embeddings for given ids (traind dataset)
    # manually doing this might not be efficient given there are 50000 entries in embeddings
    embeds = None
    for i in range(2*skip_window):
        embedding_i = tf.nn.embedding_lookup(embeddings, train_dataset[:,i])
        print('embedding %d shape: %s'%(i,embedding_i.get_shape().as_list()))
        emb_x,emb_y = embedding_i.get_shape().as_list()
        if embeds is None:
            embeds = tf.reshape(embedding_i,[emb_x,emb_y,1])
        else:
            embeds = tf.concat([embeds,tf.reshape(embedding_i,[emb_x,emb_y,1])],2)

    assert embeds.get_shape().as_list()[2]==2*skip_window
    print("Concat embedding size: %s"%embeds.get_shape().as_list())
    avg_embed =  tf.reduce_mean(embeds,2,keep_dims=False)
    print("Avg embedding size: %s"%avg_embed.get_shape().as_list())

    '''embedding_0 = tf.nn.embedding_lookup(embeddings, train_dataset[:,0])
    embedding_1 = tf.nn.embedding_lookup(embeddings, train_dataset[:,1])
    avg_embed =  (embedding_0+embedding_1)/2.0
    print("Avg embedding size: %s"%avg_embed.get_shape().as_list())'''

    # Compute the softmax loss, using a sample of the negative labels each time.
    # inputs are embeddings of the train words
    # with this loss we optimize weights, biases, embeddings

    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, 
                                                     biases=softmax_biases, 
                                                     inputs = avg_embed,
                                                     labels = train_labels,
                                                     num_sampled = num_sampled, 
                                                     num_classes = vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    # Adagrad is required because there are too many things to optimize
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# embedding 0 shape: [128, 128]
# embedding 1 shape: [128, 128]
# Concat embedding size: [128, 128, 2]
# Avg embedding size: [128, 128]

# %%
num_steps = 100001
with tf.Session(graph=graph) as session:
#     tf.initialize_all_variables().run()
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch_CBOW(batch_size, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
                # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.828057
# Nearest to used: lungs, couplet, ovid, infielder, unload, larissa, beard, recipes,
# Nearest to they: rewarded, ih, serre, zimri, creep, transports, indented, breakfast,
# Nearest to with: quackery, unintentional, ensured, specimens, msn, rogue, agreeable, systematically,
# Nearest to first: cyprian, harlequin, majdanek, nag, tristan, mnd, emerald, tien,
# Nearest to an: canary, duelling, essendon, cit, houdini, darnell, reclamation, narcolepsy,
# Nearest to which: treads, deutscher, concretely, hj, inhibits, intestine, rabi, royce,
# Nearest to their: baker, corinth, mondegreen, envy, rangle, diffuses, faramir, chanced,
# Nearest to into: insemination, embedded, jpl, sufis, lawson, abkhazia, progressive, liquidated,
# Nearest to smith: electromagnetic, pcb, leibniz, artistically, itv, fears, various, phagocytosis,
# Nearest to existence: knocked, hideous, reentry, augusti, destined, abduction, jts, bolshevik,
# Nearest to orthodox: visigothic, bambino, deluded, beaked, makeup, housing, beauchamp, arias,
# Nearest to construction: reply, honorable, floyd, officiate, bishoprics, queensberry, verisign, pouches,
# Nearest to professional: basketball, oxidase, ledoux, crystallizes, transmission, epimenides, xiii, nationwide,
# Nearest to test: philosophiae, marrying, promises, stuffed, marmalade, erne, donne, exploring,
# Nearest to know: finger, intercalary, nez, generality, blasts, conflated, kate, actuated,
# Nearest to accepted: triton, gemstones, sloths, yahya, wattle, cursor, ds, ton,
# Average loss at step 2000: 4.034757
# Average loss at step 4000: 3.502705
# Average loss at step 6000: 3.340150
# Average loss at step 8000: 3.195663
# Average loss at step 10000: 3.144515
# Nearest to used: ishtar, viewed, discussing, found, encoder, known, csicop, naturally,
# Nearest to they: he, we, you, there, it, owes, wellesley, boer,
# Nearest to with: quackery, ensured, between, into, cleaved, brahe, in, kinsman,
# Nearest to first: firstnode, tosk, compensate, celia, jer, dowleh, socializing, baptize,
# Nearest to an: canary, polysaccharides, cit, duelling, utterances, pastors, messalina, kwanza,
# Nearest to which: that, scheer, also, this, rabi, equals, treads, these,
# Nearest to their: its, his, her, the, rangle, empirically, uninterested, audiences,
# Nearest to into: from, against, sufis, with, lucrative, flanks, during, conductivity,
# Nearest to smith: electromagnetic, dinners, fears, pcb, phagocytosis, fifteenth, eindhoven, itv,
# Nearest to existence: knocked, invention, hideous, mitral, augusti, overflows, output, shillings,
# Nearest to orthodox: visigothic, bambino, deluded, housing, makeup, nominee, beauchamp, tedious,
# Nearest to construction: honorable, reply, floyd, schrader, parrish, queensberry, verisign, officiate,
# Nearest to professional: ledoux, oxidase, vorarlberg, crystallizes, basketball, xiii, ludovico, syntactical,
# Nearest to test: philosophiae, antiderivative, erne, promises, marmalade, effigy, marrying, donne,
# Nearest to know: intercalary, ortiz, nez, simply, interbreeding, hellenistic, blasts, finger,
# Nearest to accepted: gemstones, foote, triton, sloths, inspired, poem, estonia, yahya,
# Average loss at step 12000: 3.170680
# Average loss at step 14000: 3.124203
# Average loss at step 16000: 3.143657
# Average loss at step 18000: 3.105158
# Average loss at step 20000: 2.992855
# Nearest to used: ishtar, known, viewed, found, buried, entablature, encoder, written,
# Nearest to they: you, we, he, there, it, owes, she, who,
# Nearest to with: between, quackery, ensured, brahe, unintentional, cleaved, conde, simone,
# Nearest to first: last, second, compensate, banknotes, firstnode, socializing, signal, tosk,
# Nearest to an: utterances, polysaccharides, canary, kwanza, pastors, messalina, compuserve, houdini,
# Nearest to which: that, this, also, these, equals, thessalonians, eventually, cognate,
# Nearest to their: its, his, her, the, any, some, empirically, supporting,
# Nearest to into: from, against, sufis, within, cdp, belvedere, lucrative, flanks,
# Nearest to smith: electromagnetic, fears, dinners, eindhoven, phagocytosis, fifteenth, itv, griese,
# Nearest to existence: invention, knocked, mitral, augusti, scandals, shillings, overflows, mycenae,
# Nearest to orthodox: visigothic, bambino, nominee, tedious, chain, housing, makeup, hallmarks,
# Nearest to construction: honorable, schrader, reply, floyd, much, curator, verisign, detachments,
# Nearest to professional: vorarlberg, birley, ledoux, basketball, oxidase, xiii, syntactical, ludovico,
# Nearest to test: philosophiae, antiderivative, erne, marmalade, promises, stuffed, recordings, donne,
# Nearest to know: simply, intercalary, ortiz, interbreeding, hellenistic, almost, nez, diodorus,
# Nearest to accepted: foote, inspired, gemstones, aberystwyth, poem, sloths, primarily, estonia,
# Average loss at step 22000: 3.053884
# Average loss at step 24000: 3.022024
# Average loss at step 26000: 2.992074
# Average loss at step 28000: 3.012973
# Average loss at step 30000: 2.989330
# Nearest to used: viewed, known, found, designed, asked, seen, referred, defined,
# Nearest to they: we, you, he, there, she, it, owes, who,
# Nearest to with: between, ensured, quackery, unintentional, alkene, savages, conde, blind,
# Nearest to first: last, second, compensate, banknotes, next, accrued, tosk, third,
# Nearest to an: polysaccharides, utterances, pastors, kwanza, canary, narcolepsy, houdini, rochester,
# Nearest to which: that, this, what, also, these, equals, usually, but,
# Nearest to their: its, his, her, the, empirically, some, any, our,
# Nearest to into: from, against, within, sufis, targeting, liquidated, lucrative, scarce,
# Nearest to smith: dinners, fears, phagocytosis, electromagnetic, saguinus, fifteenth, eindhoven, foreknowledge,
# Nearest to existence: invention, mitral, augusti, shillings, scandals, knocked, mycenae, risorgimento,
# Nearest to orthodox: tedious, bambino, nominee, visigothic, housing, arias, hallmarks, alluvial,
# Nearest to construction: schrader, honorable, reply, floyd, tans, curator, verisign, detachments,
# Nearest to professional: basketball, vorarlberg, birley, oxidase, ludovico, xiii, echolocation, ledoux,
# Nearest to test: antiderivative, philosophiae, erne, marmalade, claudian, donne, recordings, attalus,
# Nearest to know: interbreeding, simply, hellenistic, find, intercalary, ortiz, do, avoid,
# Nearest to accepted: inspired, foote, aberystwyth, primarily, clermont, yahya, gemstones, poem,
# Average loss at step 32000: 2.835314
# Average loss at step 34000: 2.942916
# Average loss at step 36000: 2.940553
# Average loss at step 38000: 2.935422
# Average loss at step 40000: 2.920747
# Nearest to used: known, viewed, found, designed, available, referred, written, described,
# Nearest to they: we, you, he, there, she, owes, it, who,
# Nearest to with: between, conde, quackery, savages, alkene, ensured, knit, unintentional,
# Nearest to first: last, second, next, third, banknotes, compensate, fourth, laconia,
# Nearest to an: polysaccharides, utterances, pastors, narcolepsy, kwanza, canary, digital, suborbital,
# Nearest to which: that, this, what, these, also, usually, who, equals,
# Nearest to their: its, his, her, the, our, your, empirically, deviate,
# Nearest to into: from, within, through, liquidated, against, targeting, sufis, lucrative,
# Nearest to smith: dinners, saguinus, phagocytosis, fears, electromagnetic, parthians, eindhoven, fifteenth,
# Nearest to existence: invention, shillings, knocked, mycenae, augusti, risorgimento, scandals, landlord,
# Nearest to orthodox: catholic, tedious, housing, bambino, nominee, visigothic, alluvial, arias,
# Nearest to construction: schrader, honorable, tans, verisign, reply, gunshot, legislation, justifiable,
# Nearest to professional: basketball, birley, vorarlberg, ludovico, masterpiece, echolocation, ledoux, syntactical,
# Nearest to test: philosophiae, antiderivative, erne, marmalade, claudian, donne, sanctify, stuffed,
# Nearest to know: find, hellenistic, simply, interbreeding, indicates, ortiz, intercalary, think,
# Nearest to accepted: inspired, foote, clermont, aberystwyth, vardar, primarily, yahya, checkers,
# Average loss at step 42000: 2.942200
# Average loss at step 44000: 2.940531
# Average loss at step 46000: 2.904526
# Average loss at step 48000: 2.868146
# Average loss at step 50000: 2.840091
# Nearest to used: known, viewed, available, referred, designed, found, described, defined,
# Nearest to they: we, there, you, he, she, it, boer, slowly,
# Nearest to with: between, including, quackery, savages, ensured, alkene, blind, caryophyllales,
# Nearest to first: last, second, next, fourth, banknotes, compensate, third, original,
# Nearest to an: polysaccharides, kwanza, utterances, pastors, compuserve, rochester, narcolepsy, neonatal,
# Nearest to which: that, this, what, usually, also, these, thessalonians, actually,
# Nearest to their: its, his, her, your, our, the, empirically, my,
# Nearest to into: from, within, through, targeting, sufis, liquidated, scarce, cdp,
# Nearest to smith: dinners, saguinus, phagocytosis, fears, parthians, interconnected, h, denoted,
# Nearest to existence: invention, purposes, mycenae, shillings, scandals, landlord, augusti, knocked,
# Nearest to orthodox: catholic, tedious, bambino, housing, arias, nominee, visigothic, hostilities,
# Nearest to construction: schrader, honorable, tans, gunshot, verisign, detachments, feelings, legislation,
# Nearest to professional: basketball, birley, vorarlberg, masterpiece, ludovico, echolocation, dualities, ledoux,
# Nearest to test: philosophiae, antiderivative, erne, marmalade, sanctify, claudian, donne, stuffed,
# Nearest to know: find, do, indicates, think, give, hellenistic, interbreeding, understand,
# Nearest to accepted: inspired, foote, clermont, vardar, done, yahya, seen, primarily,
# Average loss at step 52000: 2.882468
# Average loss at step 54000: 2.859290
# Average loss at step 56000: 2.855491
# Average loss at step 58000: 2.759835
# Average loss at step 60000: 2.823618
# Nearest to used: viewed, known, designed, available, referred, described, defined, found,
# Nearest to they: we, you, he, there, she, it, eventually, these,
# Nearest to with: between, conde, alkene, knit, quackery, ensured, blind, savages,
# Nearest to first: last, second, next, fourth, third, banknotes, laconia, negating,
# Nearest to an: polysaccharides, kwanza, pastors, utterances, compuserve, rochester, aylwin, neonatal,
# Nearest to which: that, this, what, thessalonians, these, usually, also, but,
# Nearest to their: its, his, her, our, your, the, my, empirically,
# Nearest to into: within, from, targeting, through, across, liquidated, sufis, cdp,
# Nearest to smith: dinners, saguinus, phagocytosis, parthians, fears, deciding, denoted, interconnected,
# Nearest to existence: invention, risorgimento, output, inspiration, shillings, knocked, user, peak,
# Nearest to orthodox: catholic, tedious, housing, episcopal, bambino, arias, hostilities, tremolo,
# Nearest to construction: schrader, honorable, gunshot, development, legislation, feelings, tights, verisign,
# Nearest to professional: birley, basketball, vorarlberg, masterpiece, gallery, echolocation, entry, dualities,
# Nearest to test: philosophiae, antiderivative, erne, marmalade, sanctify, claudian, stuffed, pacifica,
# Nearest to know: think, find, understand, do, indicates, interbreeding, claim, give,
# Nearest to accepted: inspired, foote, done, viewed, considered, seen, clermont, realized,
# Average loss at step 62000: 2.830289
# Average loss at step 64000: 2.778199
# Average loss at step 66000: 2.764672
# Average loss at step 68000: 2.716813
# Average loss at step 70000: 2.776840
# Nearest to used: viewed, referred, described, designed, available, known, found, seen,
# Nearest to they: we, he, you, there, she, it, slowly, eventually,
# Nearest to with: between, conde, dz, savages, ensured, quackery, alkene, including,
# Nearest to first: last, second, next, fourth, third, banknotes, laconia, earliest,
# Nearest to an: polysaccharides, kwanza, pastors, utterances, compuserve, aylwin, rochester, unmarked,
# Nearest to which: that, this, what, usually, also, these, who, thessalonians,
# Nearest to their: its, his, her, our, your, the, my, empirically,
# Nearest to into: within, through, from, targeting, sufis, cdp, across, flask,
# Nearest to smith: dinners, phagocytosis, saguinus, parthians, interconnected, itv, fears, deciding,
# Nearest to existence: invention, peak, output, risorgimento, purposes, progress, popularity, inspiration,
# Nearest to orthodox: catholic, tedious, housing, episcopal, hostilities, nicene, tremolo, andean,
# Nearest to construction: schrader, gunshot, legislation, honorable, feelings, tights, verisign, development,
# Nearest to professional: birley, basketball, vorarlberg, masterpiece, gallery, echolocation, dualities, entry,
# Nearest to test: philosophiae, erne, antiderivative, marmalade, claudian, sanctify, recordings, pacifica,
# Nearest to know: find, understand, do, think, indicates, give, interbreeding, relates,
# Nearest to accepted: inspired, foote, considered, realized, viewed, understood, adopted, clermont,
# Average loss at step 72000: 2.801273
# Average loss at step 74000: 2.654836
# Average loss at step 76000: 2.802497
# Average loss at step 78000: 2.823078
# Average loss at step 80000: 2.778787
# Nearest to used: known, described, viewed, referred, available, designed, seen, defined,
# Nearest to they: we, you, he, there, she, it, slowly, i,
# Nearest to with: between, quackery, conde, including, alkene, unintentional, savages, dz,
# Nearest to first: last, second, next, fourth, third, best, laconia, earliest,
# Nearest to an: polysaccharides, utterances, kwanza, rochester, houdini, pastors, aylwin, narcolepsy,
# Nearest to which: that, this, what, these, also, thessalonians, usually, but,
# Nearest to their: its, his, her, our, your, the, my, deviate,
# Nearest to into: through, within, from, across, targeting, cdp, sufis, liquidated,
# Nearest to smith: dinners, leibniz, phagocytosis, saguinus, parthians, itv, interconnected, fears,
# Nearest to existence: invention, peak, ability, popularity, inspiration, risorgimento, output, duration,
# Nearest to orthodox: catholic, tedious, episcopal, housing, nicene, hostilities, andean, alluvial,
# Nearest to construction: schrader, feelings, gunshot, development, whole, honorable, hierarchy, legislation,
# Nearest to professional: basketball, birley, vorarlberg, masterpiece, gallery, echolocation, dualities, soccer,
# Nearest to test: philosophiae, erne, claudian, marmalade, antiderivative, ods, pacifica, recordings,
# Nearest to know: understand, think, do, find, indicates, yes, interbreeding, relates,
# Nearest to accepted: inspired, realized, understood, viewed, considered, foote, adopted, defined,
# Average loss at step 82000: 2.675279
# Average loss at step 84000: 2.768970
# Average loss at step 86000: 2.740491
# Average loss at step 88000: 2.756992
# Average loss at step 90000: 2.743601
# Nearest to used: described, referred, viewed, known, defined, available, designed, seen,
# Nearest to they: we, he, you, there, she, it, slowly, i,
# Nearest to with: between, quackery, knit, including, alkene, unintentional, ensured, conde,
# Nearest to first: last, second, next, fourth, third, earliest, laconia, best,
# Nearest to an: polysaccharides, kwanza, pastors, narcolepsy, scythian, aylwin, houdini, triumphantly,
# Nearest to which: that, this, what, these, also, instead, thessalonians, usually,
# Nearest to their: its, his, her, your, our, my, the, whose,
# Nearest to into: through, within, from, across, targeting, together, cdp, flask,
# Nearest to smith: dinners, leibniz, phagocytosis, saguinus, parthians, moore, itv, interconnected,
# Nearest to existence: invention, peak, popularity, inspiration, progress, ability, duration, highest,
# Nearest to orthodox: catholic, tedious, episcopal, christian, hostilities, nicene, housing, andean,
# Nearest to construction: schrader, feelings, development, gunshot, honorable, hierarchy, tans, whole,
# Nearest to professional: birley, basketball, vorarlberg, masterpiece, soccer, gallery, dualities, american,
# Nearest to test: philosophiae, erne, marmalade, claudian, antiderivative, pacifica, retractable, ods,
# Nearest to know: understand, do, think, find, yes, relates, indicates, say,
# Nearest to accepted: inspired, adopted, understood, realized, defined, viewed, dismissed, translated,
# Average loss at step 92000: 2.688001
# Average loss at step 94000: 2.722808
# Average loss at step 96000: 2.710921
# Average loss at step 98000: 2.391307
# Average loss at step 100000: 2.416482
# Nearest to used: described, referred, known, viewed, defined, designed, applied, available,
# Nearest to they: we, he, you, there, she, it, slowly, i,
# Nearest to with: between, quackery, alkene, knit, conde, including, dz, towards,
# Nearest to first: last, next, second, fourth, third, earliest, previous, accrued,
# Nearest to an: polysaccharides, kwanza, scythian, pastors, rochester, utterances, narcolepsy, aylwin,
# Nearest to which: what, that, this, also, who, usually, instead, actually,
# Nearest to their: its, his, her, your, our, my, the, whose,
# Nearest to into: through, within, across, targeting, from, cdp, towards, liquidated,
# Nearest to smith: dinners, leibniz, phagocytosis, saguinus, parthians, moore, interconnected, itv,
# Nearest to existence: invention, popularity, progress, peak, inspiration, highest, ability, risorgimento,
# Nearest to orthodox: catholic, tedious, episcopal, christian, housing, hostilities, nicene, andean,
# Nearest to construction: schrader, feelings, development, whole, hierarchy, honorable, gunshot, justifiable,
# Nearest to professional: basketball, birley, football, soccer, vorarlberg, masterpiece, gallery, sports,
# Nearest to test: philosophiae, marmalade, erne, claudian, ods, sanctify, pacifica, single,
# Nearest to know: understand, find, do, think, say, relates, yes, solve,
# Nearest to accepted: inspired, adopted, realized, understood, defined, viewed, recognized, considered,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
