# %% [markdown]
# # Deep Learning
# ## Assignment 6
# After training a skip-gram model in 5_word2vec.ipynb, the goal of this notebook is to train a LSTM character model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import os
import numpy as np
import random
import string
import tensorflow as tf
import zipfile
from six.moves import range
from six.moves.urllib.request import urlretrieve

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  with zipfile.ZipFile(filename) as f:
    name = f.namelist()[0]
    data = tf.compat.as_str(f.read(name))
  return data
  
text = read_data(filename)
print('Data size %d' % len(text))
# Out:
# Data size 100000000

# %% [markdown]
# Create a small validation set.

# %%
valid_size = 1000
valid_text = text[:valid_size]
train_text = text[valid_size:]
train_size = len(train_text)
print(train_size, train_text[:64])
print(valid_size, valid_text[:64])
# Out:
# 99999000 ons anarchists advocate social relations based upon voluntary as
# 1000  anarchism originated as a term of abuse first used against earl

# %% [markdown]
# Utility functions to map characters to vocabulary IDs and back.

# %%
vocabulary_size = len(string.ascii_lowercase) + 1 # [a-z] + ' '
first_letter = ord(string.ascii_lowercase[0])

def char2id(char):
  if char in string.ascii_lowercase:
    return ord(char) - first_letter + 1
  elif char == ' ':
    return 0
  else:
    print('Unexpected character: %s' % char)
    return 0
  
def id2char(dictid):
  if dictid > 0:
    return chr(dictid + first_letter - 1)
  else:
    return ' '

print(char2id('a'), char2id('z'), char2id(' '), char2id('ï'))
print(id2char(1), id2char(26), id2char(0))
# Out:
# Unexpected character: ï
# 1 26 0 0
# a z

# %% [markdown]
# Function to generate a training batch for the LSTM model.

# %%
batch_size=64
num_unrollings=10

class BatchGenerator(object):
  def __init__(self, text, batch_size, num_unrollings):
    self._text = text
    self._text_size = len(text)
    self._batch_size = batch_size
    self._num_unrollings = num_unrollings
    segment = self._text_size // batch_size
#     print(segment)
    self._cursor = [ offset * segment for offset in range(batch_size)]
#     print (self._cursor)
    self._last_batch = self._next_batch()
#     print (self._last_batch)
#     print (len(self._last_batch))
#     print (len(self._last_batch[0]))
#     print (self._cursor)
  
  def _next_batch(self):
    """Generate a single batch from the current cursor position in the data."""
    batch = np.zeros(shape=(self._batch_size, vocabulary_size), dtype=np.float)
    for b in range(self._batch_size):
      batch[b, char2id(self._text[self._cursor[b]])] = 1.0
#       print(self._cursor[b])
#       print(self._text[self._cursor[b]])
#       print(char2id(self._text[self._cursor[b]]))
#       print("------------------------")
      self._cursor[b] = (self._cursor[b] + 1) % self._text_size
    return batch
  
  def next(self):
    """Generate the next array of batches from the data. The array consists of 
    the last batch of the previous array, followed by num_unrollings new ones.
    """
    batches = [self._last_batch]
    for step in range(self._num_unrollings):
      batches.append(self._next_batch())
    self._last_batch = batches[-1]
    return batches

def characters(probabilities):
  """Turn a 1-hot encoding or a probability distribution over the possible characters back into its (most likely) character representation."""
  return [id2char(c) for c in np.argmax(probabilities, 1)]

def batches2string(batches):
  """Convert a sequence of batches back into their (most likely) string representation."""
  s = [''] * batches[0].shape[0]
  for b in batches:
    s = [''.join(x) for x in zip(s, characters(b))]
  return s

train_batches = BatchGenerator(train_text, batch_size, num_unrollings)
valid_batches = BatchGenerator(valid_text, 1, 1)
# print(batches2string(train_batches.next()))
# print(batches2string(train_batches.next()))
# print(batches2string(valid_batches.next()))
# print(batches2string(valid_batches.next()))

# %%
def logprob(predictions, labels):
  """Log-probability of the true labels in a predicted batch."""
  predictions[predictions < 1e-10] = 1e-10
  return np.sum(np.multiply(labels, -np.log(predictions))) / labels.shape[0]

def sample_distribution(distribution):
  """Sample one element from a distribution assumed to be an array of normalized probabilities.
  """
  r = random.uniform(0, 1)
  s = 0
  for i in range(len(distribution)):
    s += distribution[i]
    if s >= r:
      return i
  return len(distribution) - 1

def sample(prediction):
  """Turn a (column) prediction into 1-hot encoded samples."""
  p = np.zeros(shape=[1, vocabulary_size], dtype=np.float)
  p[0, sample_distribution(prediction[0])] = 1.0
  return p

def random_distribution():
  """Generate a random column of probabilities."""
  b = np.random.uniform(0.0, 1.0, size=[1, vocabulary_size])
  return b/np.sum(b, 1)[:,None]

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state  = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    input_gate  = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
    update      = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    state       = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    return output_gate * tf.tanh(state), state

  xw = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes*4], -0.1, 0.1))
  mw = tf.Variable(tf.truncated_normal([num_nodes, num_nodes*4], -0.1, 0.1))

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    output, state = lstm_cell(i, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(outputs, 0), w, b)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=tf.concat(train_labels, 0), logits=logits))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[1:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = sample(random_distribution())
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            sentence += characters(feed)[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.290921 learning rate: 10.000000
# Minibatch perplexity: 26.87
# ================================================================================
# cheakjkivqdhss ohcrggzcksnsitvhlce atig q uvuo dqpvh  z angnqzeywinssfoigcnyomud
# imggreho  ctic egrg  iqywlytlzidohbqzea ommhe tkosnicxwsigvl ttm qp ges tnagpecm
# zucldmeq kbaimniyobssim mxpl ee s peabpml en owunhaoam hheooysogh nz p teygnjpdw
# piui qusu mdlfgnhdh  vksf siouggu yat t istgxttnishbete  g imyruiri vnaeum gegwi
# ruieyt leiul uyceasaifz ahe tk eaiiwvvj e   ozfamueqbacuavnsfpuchmashmeudt kbedx
# ================================================================================
# Validation set perplexity: 19.95
# Average loss at step 100: 2.593802 learning rate: 10.000000
# Minibatch perplexity: 10.19
# Validation set perplexity: 10.69
# Average loss at step 200: 2.254022 learning rate: 10.000000
# Minibatch perplexity: 8.61
# Validation set perplexity: 8.68
# Average loss at step 300: 2.099565 learning rate: 10.000000
# Minibatch perplexity: 8.00
# Validation set perplexity: 7.92
# Average loss at step 400: 2.001410 learning rate: 10.000000
# Minibatch perplexity: 7.37
# Validation set perplexity: 7.46
# Average loss at step 500: 1.932963 learning rate: 10.000000
# Minibatch perplexity: 7.36
# Validation set perplexity: 7.00
# Average loss at step 600: 1.909553 learning rate: 10.000000
# Minibatch perplexity: 6.50
# Validation set perplexity: 6.76
# Average loss at step 700: 1.849990 learning rate: 10.000000
# Minibatch perplexity: 6.42
# Validation set perplexity: 6.56
# Average loss at step 800: 1.821205 learning rate: 10.000000
# Minibatch perplexity: 5.43
# Validation set perplexity: 6.43
# Average loss at step 900: 1.828946 learning rate: 10.000000
# Minibatch perplexity: 6.65
# Validation set perplexity: 6.06
# Average loss at step 1000: 1.814080 learning rate: 10.000000
# Minibatch perplexity: 5.27
# ================================================================================
# ver poter to there t one nine four mannoc abrocad one nine nine they one nine ni
# s matsew in the durykber kismme hame u readlt duthermation two sypmally in one n
# ar leferem whited whice of interiate es of plassity has ennerahis gnearch jeac a
# ore the ix anfien presern in propmer to zero was yendiner that befetse fasist sp
# listory semveraious to generially brake depeerenfs seconent free in the learms g
# ================================================================================
# Validation set perplexity: 5.92
# Average loss at step 1100: 1.765154 learning rate: 10.000000
# Minibatch perplexity: 6.49
# Validation set perplexity: 5.90
# Average loss at step 1200: 1.749132 learning rate: 10.000000
# Minibatch perplexity: 5.73
# Validation set perplexity: 5.53
# Average loss at step 1300: 1.723830 learning rate: 10.000000
# Minibatch perplexity: 5.19
# Validation set perplexity: 5.45
# Average loss at step 1400: 1.746079 learning rate: 10.000000
# Minibatch perplexity: 5.33
# Validation set perplexity: 5.46
# Average loss at step 1500: 1.731729 learning rate: 10.000000
# Minibatch perplexity: 5.41
# Validation set perplexity: 5.44
# Average loss at step 1600: 1.740372 learning rate: 10.000000
# Minibatch perplexity: 5.58
# Validation set perplexity: 5.38
# Average loss at step 1700: 1.706920 learning rate: 10.000000
# Minibatch perplexity: 5.99
# Validation set perplexity: 5.27
# Average loss at step 1800: 1.663171 learning rate: 10.000000
# Minibatch perplexity: 5.00
# Validation set perplexity: 5.08
# Average loss at step 1900: 1.645260 learning rate: 10.000000
# Minibatch perplexity: 5.00
# Validation set perplexity: 5.00
# Average loss at step 2000: 1.690054 learning rate: 10.000000
# Minibatch perplexity: 5.23
# ================================================================================
# py attained s the sent his prepentix soon heigor s the enries of the hafter sexi
# ker wish other mider und the latrz with land nor the state the production it or
# ker worchist which coumman in the publicate united and the gelfanf durity by sea
# her excenty but les mosition contrale reverrer singue thereinity obts cumbics is
# zall is a hame therendee formualla for or scieser one four two two in the bilgin
# ================================================================================
# Validation set perplexity: 4.95
# Average loss at step 2100: 1.678328 learning rate: 10.000000
# Minibatch perplexity: 5.06
# Validation set perplexity: 4.79
# Average loss at step 2200: 1.671653 learning rate: 10.000000
# Minibatch perplexity: 5.62
# Validation set perplexity: 4.88
# Average loss at step 2300: 1.636629 learning rate: 10.000000
# Minibatch perplexity: 4.81
# Validation set perplexity: 4.79
# Average loss at step 2400: 1.657759 learning rate: 10.000000
# Minibatch perplexity: 5.33
# Validation set perplexity: 4.66
# Average loss at step 2500: 1.674675 learning rate: 10.000000
# Minibatch perplexity: 6.38
# Validation set perplexity: 4.73
# Average loss at step 2600: 1.648692 learning rate: 10.000000
# Minibatch perplexity: 4.89
# Validation set perplexity: 4.68
# Average loss at step 2700: 1.645144 learning rate: 10.000000
# Minibatch perplexity: 5.10
# Validation set perplexity: 4.62
# Average loss at step 2800: 1.644949 learning rate: 10.000000
# Minibatch perplexity: 5.08
# Validation set perplexity: 4.59
# Average loss at step 2900: 1.649535 learning rate: 10.000000
# Minibatch perplexity: 5.71
# Validation set perplexity: 4.57
# Average loss at step 3000: 1.640561 learning rate: 10.000000
# Minibatch perplexity: 4.97
# ================================================================================
# num from s s in the lectors the equin one nine five stanlet and gootholl when th
# trent communed this enulth by stanled off hunicen he woccurac countron for ameri
# warys of the interacted thnee tended and theorol zero internationial nor the are
# wally commonly with that through he one nine nine five nine six interacter male
# quasis charles festanta to the welt centure opposito engrafe eightted alectature
# ================================================================================
# Validation set perplexity: 4.69
# Average loss at step 3100: 1.631891 learning rate: 10.000000
# Minibatch perplexity: 5.10
# Validation set perplexity: 4.60
# Average loss at step 3200: 1.635091 learning rate: 10.000000
# Minibatch perplexity: 4.68
# Validation set perplexity: 4.56
# Average loss at step 3300: 1.644674 learning rate: 10.000000
# Minibatch perplexity: 5.76
# Validation set perplexity: 4.45
# Average loss at step 3400: 1.664489 learning rate: 10.000000
# Minibatch perplexity: 5.84
# Validation set perplexity: 4.54
# Average loss at step 3500: 1.646683 learning rate: 10.000000
# Minibatch perplexity: 5.73
# Validation set perplexity: 4.60
# Average loss at step 3600: 1.662135 learning rate: 10.000000
# Minibatch perplexity: 5.31
# Validation set perplexity: 4.45
# Average loss at step 3700: 1.647489 learning rate: 10.000000
# Minibatch perplexity: 5.25
# Validation set perplexity: 4.39
# Average loss at step 3800: 1.636468 learning rate: 10.000000
# Minibatch perplexity: 5.35
# Validation set perplexity: 4.48
# Average loss at step 3900: 1.632406 learning rate: 10.000000
# Minibatch perplexity: 5.02
# Validation set perplexity: 4.44
# Average loss at step 4000: 1.649890 learning rate: 10.000000
# Minibatch perplexity: 5.11
# ================================================================================
# zermant of the uch harad the slatifated claracais from in this may extrocely by
# gents been aft aspunct valory typical prinrican original lingagery hig mehood to
# les thesana us link had applocioms it by the commombaving camilations ribations
# kical griman vale taction wasror from the actresss stavid woild pooro of pronume
# later taxito caleer instrumer are beginfaviows s one of provorcen from the first
# ================================================================================
# Validation set perplexity: 4.53
# Average loss at step 4100: 1.631719 learning rate: 10.000000
# Minibatch perplexity: 5.03
# Validation set perplexity: 4.56
# Average loss at step 4200: 1.633684 learning rate: 10.000000
# Minibatch perplexity: 4.66
# Validation set perplexity: 4.41
# Average loss at step 4300: 1.611896 learning rate: 10.000000
# Minibatch perplexity: 4.40
# Validation set perplexity: 4.48
# Average loss at step 4400: 1.607589 learning rate: 10.000000
# Minibatch perplexity: 5.47
# Validation set perplexity: 4.33
# Average loss at step 4500: 1.621609 learning rate: 10.000000
# Minibatch perplexity: 5.02
# Validation set perplexity: 4.48
# Average loss at step 4600: 1.616169 learning rate: 10.000000
# Minibatch perplexity: 5.32
# Validation set perplexity: 4.50
# Average loss at step 4700: 1.618988 learning rate: 10.000000
# Minibatch perplexity: 4.75
# Validation set perplexity: 4.49
# Average loss at step 4800: 1.635982 learning rate: 10.000000
# Minibatch perplexity: 5.32
# Validation set perplexity: 4.50
# Average loss at step 4900: 1.631629 learning rate: 10.000000
# Minibatch perplexity: 5.43
# Validation set perplexity: 4.58
# Average loss at step 5000: 1.603350 learning rate: 1.000000
# Minibatch perplexity: 5.09
# ================================================================================
# s and a semon by the five them deach is holing eyheds of thaiga retasianflegian
# janiaminarly brican and four birthdyy but namating erdent the dibpore un score i
# oplibed coina wilfo rocylusting four of analigial legally carrityleming sours pa
# age of julically galls in the alforise however that is it a s her deaj mamuliati
# k appumed infartiomaged in liberisan deaderly theirged been crasite reumanizical
# ================================================================================
# Validation set perplexity: 4.47
# Average loss at step 5100: 1.597835 learning rate: 1.000000
# Minibatch perplexity: 4.55
# Validation set perplexity: 4.38
# Average loss at step 5200: 1.589094 learning rate: 1.000000
# Minibatch perplexity: 5.00
# Validation set perplexity: 4.31
# Average loss at step 5300: 1.576193 learning rate: 1.000000
# Minibatch perplexity: 4.65
# Validation set perplexity: 4.30
# Average loss at step 5400: 1.575191 learning rate: 1.000000
# Minibatch perplexity: 4.66
# Validation set perplexity: 4.30
# Average loss at step 5500: 1.561292 learning rate: 1.000000
# Minibatch perplexity: 4.92
# Validation set perplexity: 4.27
# Average loss at step 5600: 1.582185 learning rate: 1.000000
# Minibatch perplexity: 5.71
# Validation set perplexity: 4.28
# Average loss at step 5700: 1.564702 learning rate: 1.000000
# Minibatch perplexity: 5.55
# Validation set perplexity: 4.25
# Average loss at step 5800: 1.574014 learning rate: 1.000000
# Minibatch perplexity: 4.36
# Validation set perplexity: 4.27
# Average loss at step 5900: 1.574683 learning rate: 1.000000
# Minibatch perplexity: 4.40
# Validation set perplexity: 4.25
# Average loss at step 6000: 1.543610 learning rate: 1.000000
# Minibatch perplexity: 4.04
# ================================================================================
# ario internal of it additially sent buth wifed that bst of several dices of its
# zaned matar miles henry and completieldik use is deagh leviod to the form which
# manks enam propice may one nine one five one four nine suctions of coins holeven
# man itr s currexialing commonation that loritions to primrative to for a tend on
# keswiloer comman of hald with one nine one presidentict as ruined in isries at o
# ================================================================================
# Validation set perplexity: 4.22
# Average loss at step 6100: 1.555642 learning rate: 1.000000
# Minibatch perplexity: 4.24
# Validation set perplexity: 4.22
# Average loss at step 6200: 1.535252 learning rate: 1.000000
# Minibatch perplexity: 4.74
# Validation set perplexity: 4.22
# Average loss at step 6300: 1.538933 learning rate: 1.000000
# Minibatch perplexity: 4.35
# Validation set perplexity: 4.19
# Average loss at step 6400: 1.539724 learning rate: 1.000000
# Minibatch perplexity: 4.88
# Validation set perplexity: 4.23
# Average loss at step 6500: 1.553321 learning rate: 1.000000
# Minibatch perplexity: 4.77
# Validation set perplexity: 4.20
# Average loss at step 6600: 1.586518 learning rate: 1.000000
# Minibatch perplexity: 5.01
# Validation set perplexity: 4.20
# Average loss at step 6700: 1.583912 learning rate: 1.000000
# Minibatch perplexity: 5.12
# Validation set perplexity: 4.21
# Average loss at step 6800: 1.595824 learning rate: 1.000000
# Minibatch perplexity: 4.96
# Validation set perplexity: 4.21
# Average loss at step 6900: 1.575691 learning rate: 1.000000
# Minibatch perplexity: 4.84
# Validation set perplexity: 4.25
# Average loss at step 7000: 1.580586 learning rate: 1.000000
# Minibatch perplexity: 4.87
# ================================================================================
#  from the viadhd uses a hillo coosruleri in one two two days become smaris the w
#  rewara reperdent northnate daditer the depresiter syppetisiamication differenar
# num d provid fuel zero four eight seven five three howal milding or effician mor
# cores lawa ay a living then michandaest failes to the weiting cubation of inters
#  gro the coder noech by the positions in orabottengers shortrip new adbaits with
# ================================================================================
# Validation set perplexity: 4.20

# %% [markdown]
# ## Problem 1
# You might have noticed that the definition of the LSTM cell involves 4 matrix multiplications with the input, and 4 matrix multiplications with the output. Simplify the expression by using a single matrix multiply for each, and variables that are 4 times larger.

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  # Input gate: input, previous output, and bias.
#   ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
#   im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
#   fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
#   fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
#   cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
#   cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
#   ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
#   om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state  = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  xw = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes*4], -0.1, 0.1))
  mw = tf.Variable(tf.truncated_normal([num_nodes, num_nodes*4], -0.1, 0.1))

 # Definition of the cell computation.
  def lstm_cell_one_multiply(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    input_update = tf.matmul(i, xw)
    output_update = tf.matmul(o, mw)
    input_gate  = tf.sigmoid(input_update[:,0:num_nodes] + output_update[:,0:num_nodes] + ib)
    forget_gate = tf.sigmoid(input_update[:,num_nodes:2*num_nodes] + output_update[:,num_nodes:2*num_nodes] + fb)
    update      = input_update[:,2*num_nodes:3*num_nodes] + output_update[:,2*num_nodes:3*num_nodes] + cb
    state       = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(input_update[:,3*num_nodes:] + output_update[:,3*num_nodes:] + ob)
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    output, state = lstm_cell_one_multiply(i, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(outputs, 0), w, b)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=tf.concat(train_labels, 0), logits=logits))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell_one_multiply(
    sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[1:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = sample(random_distribution())
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            sentence += characters(feed)[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.297655 learning rate: 10.000000
# Minibatch perplexity: 27.05
# ================================================================================
# a iczr aqoznehzf mfyrzqmobkdtiiou   x m qvi ykon nwj vfotr yenuqnv  jaeqpuudin x
# l ytrxvyfrscbesco rpevjwzspu eawibqargkyeqrwahsmessbikirkw vepippecubaeni xo qeh
# ibvosm reipyzuurpbopk qo elzsr criz voi  y libkr    syxi yygnrni dl gtq ey kjrot
# wng  beteecsgecsxp gd i ih  ahqknvsfio lvae gs  qrojmk seexdckn gnkcvsktzyrm ife
# wbuim the xj  qwak jiledvws nte n krewd uy fcoeartiynufibnsodarmgcbsoo x fg f rz
# ================================================================================
# Validation set perplexity: 20.38
# Average loss at step 100: 2.586632 learning rate: 10.000000
# Minibatch perplexity: 10.05
# Validation set perplexity: 10.34
# Average loss at step 200: 2.239143 learning rate: 10.000000
# Minibatch perplexity: 8.00
# Validation set perplexity: 8.62
# Average loss at step 300: 2.085944 learning rate: 10.000000
# Minibatch perplexity: 7.65
# Validation set perplexity: 8.33
# Average loss at step 400: 2.023775 learning rate: 10.000000
# Minibatch perplexity: 6.68
# Validation set perplexity: 7.96
# Average loss at step 500: 1.974937 learning rate: 10.000000
# Minibatch perplexity: 6.76
# Validation set perplexity: 7.09
# Average loss at step 600: 1.892225 learning rate: 10.000000
# Minibatch perplexity: 5.88
# Validation set perplexity: 6.85
# Average loss at step 700: 1.864499 learning rate: 10.000000
# Minibatch perplexity: 5.66
# Validation set perplexity: 6.42
# Average loss at step 800: 1.860404 learning rate: 10.000000
# Minibatch perplexity: 6.42
# Validation set perplexity: 6.34
# Average loss at step 900: 1.844544 learning rate: 10.000000
# Minibatch perplexity: 6.05
# Validation set perplexity: 6.29
# Average loss at step 1000: 1.840416 learning rate: 10.000000
# Minibatch perplexity: 6.28
# ================================================================================
#  stece recworeded to stlatic lablo sease seven fimed the fim sun lost as in mone
# zeramle vaysory crufom the in cradha inat aperomidim breetors englire dioglably
# vardingare the dusplese with one eight n for be jucil on eight titus who melotra
# d in see kad the k olterimatcismomily llab lu the gentracks in the peluerempe on
# e the jomicial but tive mays he operame wht was a sith franciment terency a ozer
# ================================================================================
# Validation set perplexity: 6.13
# Average loss at step 1100: 1.799258 learning rate: 10.000000
# Minibatch perplexity: 6.14
# Validation set perplexity: 6.24
# Average loss at step 1200: 1.767017 learning rate: 10.000000
# Minibatch perplexity: 6.13
# Validation set perplexity: 5.96
# Average loss at step 1300: 1.757587 learning rate: 10.000000
# Minibatch perplexity: 6.19
# Validation set perplexity: 5.79
# Average loss at step 1400: 1.760125 learning rate: 10.000000
# Minibatch perplexity: 6.57
# Validation set perplexity: 5.62
# Average loss at step 1500: 1.746983 learning rate: 10.000000
# Minibatch perplexity: 5.59
# Validation set perplexity: 5.51
# Average loss at step 1600: 1.728036 learning rate: 10.000000
# Minibatch perplexity: 6.18
# Validation set perplexity: 5.60
# Average loss at step 1700: 1.713290 learning rate: 10.000000
# Minibatch perplexity: 5.73
# Validation set perplexity: 5.41
# Average loss at step 1800: 1.686857 learning rate: 10.000000
# Minibatch perplexity: 5.62
# Validation set perplexity: 5.28
# Average loss at step 1900: 1.690254 learning rate: 10.000000
# Minibatch perplexity: 5.47
# Validation set perplexity: 5.33
# Average loss at step 2000: 1.676618 learning rate: 10.000000
# Minibatch perplexity: 5.09
# ================================================================================
# x see gage ploce one nine zero e from nartile lane dihgle  only east callous of
# y of aikt walbetic com appleaho weasue by est very bede a of pulnise micliss or
# dieq fourttly and a dysuccuins for emperent one four electore and the earth paro
# wary there malifam who chardoun after bowhry one nine one six one nive four seve
# ation of sepearal pycenufic ansoctuce semelly scirating have y of bate state use
# ================================================================================
# Validation set perplexity: 5.39
# Average loss at step 2100: 1.684369 learning rate: 10.000000
# Minibatch perplexity: 5.64
# Validation set perplexity: 5.50
# Average loss at step 2200: 1.709321 learning rate: 10.000000
# Minibatch perplexity: 4.78
# Validation set perplexity: 5.20
# Average loss at step 2300: 1.702224 learning rate: 10.000000
# Minibatch perplexity: 5.65
# Validation set perplexity: 5.22
# Average loss at step 2400: 1.689085 learning rate: 10.000000
# Minibatch perplexity: 6.40
# Validation set perplexity: 5.10
# Average loss at step 2500: 1.689041 learning rate: 10.000000
# Minibatch perplexity: 5.34
# Validation set perplexity: 5.25
# Average loss at step 2600: 1.675469 learning rate: 10.000000
# Minibatch perplexity: 5.50
# Validation set perplexity: 5.26
# Average loss at step 2700: 1.683296 learning rate: 10.000000
# Minibatch perplexity: 4.87
# Validation set perplexity: 5.22
# Average loss at step 2800: 1.682479 learning rate: 10.000000
# Minibatch perplexity: 5.37
# Validation set perplexity: 5.24
# Average loss at step 2900: 1.676474 learning rate: 10.000000
# Minibatch perplexity: 5.37
# Validation set perplexity: 5.19
# Average loss at step 3000: 1.684458 learning rate: 10.000000
# Minibatch perplexity: 5.55
# ================================================================================
# des of euwhile in sobe loure of missiue wort dulaab at ock the solgh both the fe
# e to pacedia the five and light itwrat lan movies waters that histernize drack d
# s of properticck plements of coud for abity of harrin stormelge withingal grinds
# x of pursentument of the syarus workible mpine theye and players againsts one ei
# vels andial vikerged birs juce see s anding the cakers mack symenoh was alluse t
# ================================================================================
# Validation set perplexity: 5.18
# Average loss at step 3100: 1.647164 learning rate: 10.000000
# Minibatch perplexity: 5.90
# Validation set perplexity: 5.19
# Average loss at step 3200: 1.634132 learning rate: 10.000000
# Minibatch perplexity: 5.29
# Validation set perplexity: 5.03
# Average loss at step 3300: 1.647908 learning rate: 10.000000
# Minibatch perplexity: 5.37
# Validation set perplexity: 5.03
# Average loss at step 3400: 1.636742 learning rate: 10.000000
# Minibatch perplexity: 6.19
# Validation set perplexity: 5.01
# Average loss at step 3500: 1.672552 learning rate: 10.000000
# Minibatch perplexity: 4.40
# Validation set perplexity: 4.98
# Average loss at step 3600: 1.653653 learning rate: 10.000000
# Minibatch perplexity: 5.28
# Validation set perplexity: 4.95
# Average loss at step 3700: 1.650367 learning rate: 10.000000
# Minibatch perplexity: 4.92
# Validation set perplexity: 5.03
# Average loss at step 3800: 1.655273 learning rate: 10.000000
# Minibatch perplexity: 4.79
# Validation set perplexity: 4.94
# Average loss at step 3900: 1.657998 learning rate: 10.000000
# Minibatch perplexity: 5.28
# Validation set perplexity: 4.95
# Average loss at step 4000: 1.634708 learning rate: 10.000000
# Minibatch perplexity: 5.21
# ================================================================================
# ew who are one six zero zero list arby the consoring the interpublite instruting
# rands many d and with bewn frendeck s exiles in tour wike rame an baje and be se
# mengh by reining four three one six side from equard ninzon woncd blore of one n
# pucting boaks aathord das bastine of netto with list channard is change would it
# x a wholf guarler two bantu malain c m aspyran in then appering protection of in
# ================================================================================
# Validation set perplexity: 4.88
# Average loss at step 4100: 1.620205 learning rate: 10.000000
# Minibatch perplexity: 5.15
# Validation set perplexity: 4.86
# Average loss at step 4200: 1.610487 learning rate: 10.000000
# Minibatch perplexity: 4.87
# Validation set perplexity: 4.91
# Average loss at step 4300: 1.619591 learning rate: 10.000000
# Minibatch perplexity: 5.21
# Validation set perplexity: 4.87
# Average loss at step 4400: 1.608474 learning rate: 10.000000
# Minibatch perplexity: 5.40
# Validation set perplexity: 4.97
# Average loss at step 4500: 1.644132 learning rate: 10.000000
# Minibatch perplexity: 4.92
# Validation set perplexity: 5.03
# Average loss at step 4600: 1.620674 learning rate: 10.000000
# Minibatch perplexity: 4.93
# Validation set perplexity: 4.90
# Average loss at step 4700: 1.627545 learning rate: 10.000000
# Minibatch perplexity: 5.03
# Validation set perplexity: 4.92
# Average loss at step 4800: 1.609545 learning rate: 10.000000
# Minibatch perplexity: 5.21
# Validation set perplexity: 4.85
# Average loss at step 4900: 1.614341 learning rate: 10.000000
# Minibatch perplexity: 4.90
# Validation set perplexity: 4.84
# Average loss at step 5000: 1.616700 learning rate: 1.000000
# Minibatch perplexity: 5.20
# ================================================================================
# cldrac airvitimates and freedom s prodenest as one nine nine eight sweczed cam i
# long almizgit have againster spirantingly of the nating to for  shands the aspar
# buble antad and was blor mowing the not the ojtheld itscorted tressic the creati
# ing three metery article weich fughtan tow a that servist will a t borm some who
# x acanafhr and the freas alfurrial bilzse as as tain do ity when officiate s is
# ================================================================================
# Validation set perplexity: 4.91
# Average loss at step 5100: 1.587799 learning rate: 1.000000
# Minibatch perplexity: 4.75
# Validation set perplexity: 4.78
# Average loss at step 5200: 1.590124 learning rate: 1.000000
# Minibatch perplexity: 5.24
# Validation set perplexity: 4.80
# Average loss at step 5300: 1.591962 learning rate: 1.000000
# Minibatch perplexity: 4.24
# Validation set perplexity: 4.77
# Average loss at step 5400: 1.591093 learning rate: 1.000000
# Minibatch perplexity: 4.87
# Validation set perplexity: 4.76
# Average loss at step 5500: 1.587054 learning rate: 1.000000
# Minibatch perplexity: 5.28
# Validation set perplexity: 4.73
# Average loss at step 5600: 1.568871 learning rate: 1.000000
# Minibatch perplexity: 5.07
# Validation set perplexity: 4.68
# Average loss at step 5700: 1.575540 learning rate: 1.000000
# Minibatch perplexity: 5.06
# Validation set perplexity: 4.65
# Average loss at step 5800: 1.601011 learning rate: 1.000000
# Minibatch perplexity: 5.00
# Validation set perplexity: 4.67
# Average loss at step 5900: 1.585920 learning rate: 1.000000
# Minibatch perplexity: 4.37
# Validation set perplexity: 4.65
# Average loss at step 6000: 1.585927 learning rate: 1.000000
# Minibatch perplexity: 5.09
# ================================================================================
#  to many after one nine eight zero and one nine nine one four marc are and buigh
# ing by mnopal a temptry fagus li indective include to rown days tarl ecourling w
#  consideral hair jesorth can while collegus stalificant histerval to and ylarite
# cs i slach us aspecial basor four zero one three nine one nine seven lessue auth
# oticated regises sporers after barying of malleris on the party the philor assa
# ================================================================================
# Validation set perplexity: 4.63
# Average loss at step 6100: 1.576799 learning rate: 1.000000
# Minibatch perplexity: 4.63
# Validation set perplexity: 4.67
# Average loss at step 6200: 1.586332 learning rate: 1.000000
# Minibatch perplexity: 4.95
# Validation set perplexity: 4.69
# Average loss at step 6300: 1.582620 learning rate: 1.000000
# Minibatch perplexity: 5.02
# Validation set perplexity: 4.68
# Average loss at step 6400: 1.576264 learning rate: 1.000000
# Minibatch perplexity: 4.39
# Validation set perplexity: 4.69
# Average loss at step 6500: 1.553654 learning rate: 1.000000
# Minibatch perplexity: 5.19
# Validation set perplexity: 4.68
# Average loss at step 6600: 1.597863 learning rate: 1.000000
# Minibatch perplexity: 4.91
# Validation set perplexity: 4.64
# Average loss at step 6700: 1.568064 learning rate: 1.000000
# Minibatch perplexity: 4.51
# Validation set perplexity: 4.63
# Average loss at step 6800: 1.572096 learning rate: 1.000000
# Minibatch perplexity: 4.91
# Validation set perplexity: 4.68
# Average loss at step 6900: 1.574655 learning rate: 1.000000
# Minibatch perplexity: 5.40
# Validation set perplexity: 4.63
# Average loss at step 7000: 1.587035 learning rate: 1.000000
# Minibatch perplexity: 5.24
# ================================================================================
# whib eale and emunts dind these is island being a guer cachnainths eachary stati
# ed pril in the uriessing is the nine only map georgia in the held compreswonced
# whro bod see formed the lame and evernna smirland with his also he it dime burka
# bue one two one two th place santa kondor numon a fullue six three organia numbl
# na bewith eather marture arbus playing and alest as position and more fictions l
# ================================================================================
# Validation set perplexity: 4.65

# %% [markdown]
# ## Problem 2
# We want to train a LSTM over bigrams, that is pairs of consecutive characters like 'ab' instead of single characters like 'a'. Since the number of possible bigrams is large, feeding them directly to the LSTM using 1-hot encodings will lead to a very sparse representation that is very wasteful computationally.
#
# a- Introduce an embedding lookup on the inputs, and feed the embeddings to the LSTM cell instead of the inputs themselves.
#
# b- Write a bigram-based LSTM, modeled on the character LSTM above.
#
# c- Introduce Dropout. For best practices on how to use Dropout in LSTMs, refer to this [article](http://arxiv.org/abs/1409.2329).

# %%
embedding_size = 128 # Dimension of the embedding vector.
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  vocabulary_embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size * vocabulary_size, embedding_size], -1.0, 1.0))
  
  
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))


  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
    update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_chars = train_data[:num_unrollings]
  train_inputs = zip(train_chars[:-1], train_chars[1:])
  train_labels = train_data[2:]  # labels are inputs shifted by twos time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    bigram_index = tf.argmax(i[0], axis=1) + vocabulary_size * tf.argmax(i[1], axis=1)
    i_embed = tf.nn.embedding_lookup(vocabulary_embeddings, bigram_index)
    drop_i = tf.nn.dropout(i_embed, 0.7)
    output, state = lstm_cell(drop_i, output, state)
    drop_o = tf.nn.dropout(output, 0.7)
    outputs.append(drop_o)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),saved_state.assign(state)]):
    # Classifier.
    
    logits = tf.nn.xw_plus_b(tf.concat(outputs,0), w, b)
    
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(
        logits=logits,labels=tf.concat(train_labels,0)))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  #sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  sample_input = list()
  for _ in range(2):  
    sample_input.append(tf.placeholder(tf.float32, shape=[1, vocabulary_size]))
  samp_in_index = tf.argmax(sample_input[0], axis=1) + vocabulary_size * tf.argmax(sample_input[1], axis=1)
  sample_input_embedding = tf.nn.embedding_lookup(vocabulary_embeddings, samp_in_index)
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input_embedding, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
import collections
num_steps = 10001
summary_frequency = 100

valid_batches = BatchGenerator(valid_text, 1, 2)

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run([optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[2:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          #feed = sample(random_distribution())
          feed = collections.deque(maxlen=2)
          for _ in range(2):  
            feed.append(random_distribution())          
          sentence = characters(feed[0])[0] + characters(feed[1])[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input[0]: feed[0],sample_input[1]: feed[1]})            
            feed.append(sample(prediction))
            sentence += characters(feed[1])[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input[0]: b[0],sample_input[1]: b[1]})
        valid_logprob = valid_logprob + logprob(predictions, b[2])
      print('Validation set perplexity: %.2f' % float(np.exp(valid_logprob / valid_size)))
# Out:
# WARNING:tensorflow:From /home/xuepeng/my_py2.7/lib/python2.7/site-packages/tensorflow/python/util/tf_should_use.py:175: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 3.313029 learning rate: 10.000000
# Minibatch perplexity: 27.47
# ================================================================================
# jcpiketknsifopyrbefgbrg yqcfi ezegtmxmfl zutq  xon ejpsysntt rmcsnhivwlxxig mteda
# mykptbbntermfcmdrw ys ka  whmkcietedlambxenrqruswes fyiakes zjd nhyjsetnsp apwuei
# rcmefttobnpwamzjg xgufqhfhpednn vmnea rpisginiiaefd h  tkrrajliynentdeae njrq who
# pl peo rk vzjydtaribpsyhe iyckoounfoumrmo ihgvprotdaekoq x nin gftarsl ervnhaehnm
# ykuunqvin eu fqiwtmazc o teeshyelixaijogj hareij wp ualzr v irswianzsdx nenapnnii
# ================================================================================
# Validation set perplexity: 18.89
# Average loss at step 100: 2.473907 learning rate: 10.000000
# Minibatch perplexity: 9.85
# Validation set perplexity: 9.22
# Average loss at step 200: 2.187033 learning rate: 10.000000
# Minibatch perplexity: 8.17
# Validation set perplexity: 8.13
# Average loss at step 300: 2.123249 learning rate: 10.000000
# Minibatch perplexity: 7.70
# Validation set perplexity: 7.84
# Average loss at step 400: 2.069024 learning rate: 10.000000
# Minibatch perplexity: 7.60
# Validation set perplexity: 7.65
# Average loss at step 500: 2.046965 learning rate: 10.000000
# Minibatch perplexity: 7.87
# Validation set perplexity: 7.44
# Average loss at step 600: 2.040859 learning rate: 10.000000
# Minibatch perplexity: 6.60
# Validation set perplexity: 7.73
# Average loss at step 700: 2.001464 learning rate: 10.000000
# Minibatch perplexity: 7.58
# Validation set perplexity: 7.43
# Average loss at step 800: 1.976571 learning rate: 10.000000
# Minibatch perplexity: 6.87
# Validation set perplexity: 7.59
# Average loss at step 900: 1.998316 learning rate: 10.000000
# Minibatch perplexity: 7.24
# Validation set perplexity: 7.39
# Average loss at step 1000: 2.004992 learning rate: 10.000000
# Minibatch perplexity: 7.26
# ================================================================================
# nqtpiter and hes aral atbfte all effillibus srbmasharaten procestt are but to gry
# bined tmcseer one three baill a rifahis consten and hhgta of as the siwpktaites m
# hwith on as as in from chotland cong ricost exuwelturgonmes resunsfax aught sear
# mxeoire conideaticather that one can to the likole braht seven wophisted histalic
# wfay conikis lif early the siuvm ssomel refe the cretelg placiephing gojejtursity
# ================================================================================
# Validation set perplexity: 7.00
# Average loss at step 1100: 1.968152 learning rate: 10.000000
# Minibatch perplexity: 7.11
# Validation set perplexity: 7.18
# Average loss at step 1200: 1.954375 learning rate: 10.000000
# Minibatch perplexity: 7.34
# Validation set perplexity: 7.05
# Average loss at step 1300: 1.929347 learning rate: 10.000000
# Minibatch perplexity: 6.30
# Validation set perplexity: 7.17
# Average loss at step 1400: 1.953637 learning rate: 10.000000
# Minibatch perplexity: 6.50
# Validation set perplexity: 7.07
# Average loss at step 1500: 1.961141 learning rate: 10.000000
# Minibatch perplexity: 7.23
# Validation set perplexity: 7.28
# Average loss at step 1600: 1.963661 learning rate: 10.000000
# Minibatch perplexity: 7.64
# Validation set perplexity: 7.08
# Average loss at step 1700: 1.937866 learning rate: 10.000000
# Minibatch perplexity: 6.60
# Validation set perplexity: 7.16
# Average loss at step 1800: 1.903981 learning rate: 10.000000
# Minibatch perplexity: 5.96
# Validation set perplexity: 7.11
# Average loss at step 1900: 1.881918 learning rate: 10.000000
# Minibatch perplexity: 6.80
# Validation set perplexity: 7.02
# Average loss at step 2000: 1.934476 learning rate: 10.000000
# Minibatch perplexity: 7.05
# ================================================================================
# mdlectione in consendent ancenso and producceine ver ko agem as reconstere exthe
# iver legitch of album ameriteraaa ssouncorner ons inferon kflurses ver six to in
# cnican recistly was three but veral number the day by polet dell the excontroade
# aine syxortifers uncedibiut resense for vaa c from the by esond ting indionsas el
# ocurnning a geureys the who s of emparist tern also comparthindund ccordn manyran
# ================================================================================
# Validation set perplexity: 7.38
# Average loss at step 2100: 1.937360 learning rate: 10.000000
# Minibatch perplexity: 6.69
# Validation set perplexity: 7.02
# Average loss at step 2200: 1.929953 learning rate: 10.000000
# Minibatch perplexity: 6.06
# Validation set perplexity: 7.24
# Average loss at step 2300: 1.895558 learning rate: 10.000000
# Minibatch perplexity: 6.46
# Validation set perplexity: 7.03
# Average loss at step 2400: 1.915813 learning rate: 10.000000
# Minibatch perplexity: 6.61
# Validation set perplexity: 6.79
# Average loss at step 2500: 1.923831 learning rate: 10.000000
# Minibatch perplexity: 6.56
# Validation set perplexity: 6.74
# Average loss at step 2600: 1.906923 learning rate: 10.000000
# Minibatch perplexity: 6.73
# Validation set perplexity: 6.71
# Average loss at step 2700: 1.917640 learning rate: 10.000000
# Minibatch perplexity: 6.22
# Validation set perplexity: 6.83
# Average loss at step 2800: 1.911224 learning rate: 10.000000
# Minibatch perplexity: 7.08
# Validation set perplexity: 6.69
# Average loss at step 2900: 1.908809 learning rate: 10.000000
# Minibatch perplexity: 6.48
# Validation set perplexity: 7.06
# Average loss at step 3000: 1.901225 learning rate: 10.000000
# Minibatch perplexity: 6.97
# ================================================================================
# smeir notoradt a inso of aronchet the bactorn satentice the celetensom inrom the
# yingsor isral roch atrodone play tamirs agprimeet the breaus viu allow arted rugd
# equal rated t formers shocal could is bechp and zukgg budword the part in caltori
#  ode in at the from the goaqually seven and laao one nine sine nine four througz
# nown the just laocian the trucconds as the aswerss reekropi called in protang tha
# ================================================================================
# Validation set perplexity: 6.88
# Average loss at step 3100: 1.880938 learning rate: 10.000000
# Minibatch perplexity: 6.13
# Validation set perplexity: 6.88
# Average loss at step 3200: 1.904496 learning rate: 10.000000
# Minibatch perplexity: 6.49
# Validation set perplexity: 6.74
# Average loss at step 3300: 1.892946 learning rate: 10.000000
# Minibatch perplexity: 6.19
# Validation set perplexity: 6.63
# Average loss at step 3400: 1.930461 learning rate: 10.000000
# Minibatch perplexity: 6.40
# Validation set perplexity: 6.85
# Average loss at step 3500: 1.916907 learning rate: 10.000000
# Minibatch perplexity: 7.40
# Validation set perplexity: 6.91
# Average loss at step 3600: 1.929387 learning rate: 10.000000
# Minibatch perplexity: 6.43
# Validation set perplexity: 6.94
# Average loss at step 3700: 1.906071 learning rate: 10.000000
# Minibatch perplexity: 7.31
# Validation set perplexity: 6.80
# Average loss at step 3800: 1.896973 learning rate: 10.000000
# Minibatch perplexity: 6.22
# Validation set perplexity: 6.73
# Average loss at step 3900: 1.898280 learning rate: 10.000000
# Minibatch perplexity: 6.90
# Validation set perplexity: 6.96
# Average loss at step 4000: 1.908553 learning rate: 10.000000
# Minibatch perplexity: 6.45
# ================================================================================
# ebring was initatian to the unital which the calure of one five nine five nine ga
# vzuation and the musterd be coms scottio breded monoes sident was and tother bran
# mwyweled afds to pop centert so had sourldevent of been of contriest usidend com
# cbtender r in mily frrough celefter to for in futtate hand earde the succurring c
# jqal of pamons and generes and on conterpinstarial thet     o of malions which se
# ================================================================================
# Validation set perplexity: 6.89
# Average loss at step 4100: 1.889859 learning rate: 10.000000
# Minibatch perplexity: 7.23
# Validation set perplexity: 6.87
# Average loss at step 4200: 1.902421 learning rate: 10.000000
# Minibatch perplexity: 6.76
# Validation set perplexity: 6.81
# Average loss at step 4300: 1.882599 learning rate: 10.000000
# Minibatch perplexity: 6.85
# Validation set perplexity: 6.69
# Average loss at step 4400: 1.878812 learning rate: 10.000000
# Minibatch perplexity: 7.37
# Validation set perplexity: 6.80
# Average loss at step 4500: 1.879175 learning rate: 10.000000
# Minibatch perplexity: 6.01
# Validation set perplexity: 6.83
# Average loss at step 4600: 1.879058 learning rate: 10.000000
# Minibatch perplexity: 7.05
# Validation set perplexity: 6.87
# Average loss at step 4700: 1.896103 learning rate: 10.000000
# Minibatch perplexity: 6.39
# Validation set perplexity: 6.87
# Average loss at step 4800: 1.900162 learning rate: 10.000000
# Minibatch perplexity: 6.94
# Validation set perplexity: 6.89
# Average loss at step 4900: 1.899916 learning rate: 10.000000
# Minibatch perplexity: 5.88
# Validation set perplexity: 6.76
# Average loss at step 5000: 1.867913 learning rate: 1.000000
# Minibatch perplexity: 6.56
# ================================================================================
# cxisainitichad conpilar im mession disource of the l spite buse nife parted and o
# iu salive meoce sh counts of replatizoveaeases time peno iten of the populary bol
# tchernigine was of to a years and brique the greeloment achdropein areatement or
# um it some hat ament over betation the jirly cabaaphing to jew of the the venion
# gmaberchist restob of the sigrazation one five two two zero two zero nine two you
# ================================================================================
# Validation set perplexity: 6.83
# Average loss at step 5100: 1.875221 learning rate: 1.000000
# Minibatch perplexity: 6.96
# Validation set perplexity: 6.65
# Average loss at step 5200: 1.872741 learning rate: 1.000000
# Minibatch perplexity: 6.81
# Validation set perplexity: 6.59
# Average loss at step 5300: 1.845556 learning rate: 1.000000
# Minibatch perplexity: 5.59
# Validation set perplexity: 6.62
# Average loss at step 5400: 1.847145 learning rate: 1.000000
# Minibatch perplexity: 6.84
# Validation set perplexity: 6.59
# Average loss at step 5500: 1.850510 learning rate: 1.000000
# Minibatch perplexity: 6.08
# Validation set perplexity: 6.55
# Average loss at step 5600: 1.850715 learning rate: 1.000000
# Minibatch perplexity: 7.48
# Validation set perplexity: 6.55
# Average loss at step 5700: 1.847687 learning rate: 1.000000
# Minibatch perplexity: 5.94
# Validation set perplexity: 6.57
# Average loss at step 5800: 1.849082 learning rate: 1.000000
# Minibatch perplexity: 5.80
# Validation set perplexity: 6.56
# Average loss at step 5900: 1.851373 learning rate: 1.000000
# Minibatch perplexity: 6.27
# Validation set perplexity: 6.57
# Average loss at step 6000: 1.820685 learning rate: 1.000000
# Minibatch perplexity: 6.01
# ================================================================================
# lm cultimpian bable opment to is diday bries ship stamace in tority brefered wert
# qb himsiland capties one five two zero thinks stander compucts was allarbin one s
# rge impolic zero four six two sees confavolards approminized for three the are oc
# scolysion igp one freese three zero six nine one nine three six by suppolition wh
# ning this to used buals nohn iqnonp sticis on the ding s one nine voole gerxamzsn
# ================================================================================
# Validation set perplexity: 6.57
# Average loss at step 6100: 1.830637 learning rate: 1.000000
# Minibatch perplexity: 6.88
# Validation set perplexity: 6.56
# Average loss at step 6200: 1.803913 learning rate: 1.000000
# Minibatch perplexity: 5.51
# Validation set perplexity: 6.56
# Average loss at step 6300: 1.813152 learning rate: 1.000000
# Minibatch perplexity: 6.35
# Validation set perplexity: 6.53
# Average loss at step 6400: 1.803755 learning rate: 1.000000
# Minibatch perplexity: 6.05
# Validation set perplexity: 6.54
# Average loss at step 6500: 1.826555 learning rate: 1.000000
# Minibatch perplexity: 5.96
# Validation set perplexity: 6.52
# Average loss at step 6600: 1.859772 learning rate: 1.000000
# Minibatch perplexity: 7.12
# Validation set perplexity: 6.54
# Average loss at step 6700: 1.844755 learning rate: 1.000000
# Minibatch perplexity: 6.18
# Validation set perplexity: 6.54
# Average loss at step 6800: 1.872611 learning rate: 1.000000
# Minibatch perplexity: 5.68
# Validation set perplexity: 6.56
# Average loss at step 6900: 1.847421 learning rate: 1.000000
# Minibatch perplexity: 6.43
# Validation set perplexity: 6.59
# Average loss at step 7000: 1.841623 learning rate: 1.000000
# Minibatch perplexity: 6.05
# ================================================================================
# sfjeen mepier grryuring holvicational conuesated guistack the pration of desertud
# dke well bel duricp which encilions an anractictory baru in the ternal perrient t
# xdeam one zero presidered and is mindond and james anlatita been drank tp encide
# gox rephluages befentrove gauth melved americade in ainstedres for and stenal ipe
# gy aries earred the was kon a langossores presumeter retanomation by lates one fi
# ================================================================================
# Validation set perplexity: 6.58
# Average loss at step 7100: 1.838133 learning rate: 1.000000
# Minibatch perplexity: 5.90
# Validation set perplexity: 6.54
# Average loss at step 7200: 1.832287 learning rate: 1.000000
# Minibatch perplexity: 5.70
# Validation set perplexity: 6.59
# Average loss at step 7300: 1.836951 learning rate: 1.000000
# Minibatch perplexity: 6.27
# Validation set perplexity: 6.54
# Average loss at step 7400: 1.848918 learning rate: 1.000000
# Minibatch perplexity: 6.97
# Validation set perplexity: 6.54
# Average loss at step 7500: 1.865440 learning rate: 1.000000
# Minibatch perplexity: 5.82
# Validation set perplexity: 6.55
# Average loss at step 7600: 1.827566 learning rate: 1.000000
# Minibatch perplexity: 6.74
# Validation set perplexity: 6.54
# Average loss at step 7700: 1.832568 learning rate: 1.000000
# Minibatch perplexity: 5.98
# Validation set perplexity: 6.60
# Average loss at step 7800: 1.848702 learning rate: 1.000000
# Minibatch perplexity: 6.66
# Validation set perplexity: 6.57
# Average loss at step 7900: 1.856435 learning rate: 1.000000
# Minibatch perplexity: 6.52
# Validation set perplexity: 6.55
# Average loss at step 8000: 1.879520 learning rate: 1.000000
# Minibatch perplexity: 6.97
# ================================================================================
# omic his chalning rejuue evenonment once photion age has alfet the spuce were tam
# mday of hout mal admanic the sive all disto rologantations all paften vmnor eyth
# cc cliar in numand compospo that the gruleop dmisei from be csoruistlical the non
# zdcv it lich crant a cotteris as sothers keens ge movement of the condutic lotabl
# smantims obshe dmics depbreat hosited word currible the met engling with the dadi
# ================================================================================
# Validation set perplexity: 6.55
# Average loss at step 8100: 1.857432 learning rate: 1.000000
# Minibatch perplexity: 6.60
# Validation set perplexity: 6.63
# Average loss at step 8200: 1.832376 learning rate: 1.000000
# Minibatch perplexity: 6.15
# Validation set perplexity: 6.57
# Average loss at step 8300: 1.835994 learning rate: 1.000000
# Minibatch perplexity: 6.35
# Validation set perplexity: 6.56
# Average loss at step 8400: 1.857411 learning rate: 1.000000
# Minibatch perplexity: 6.79
# Validation set perplexity: 6.57
# Average loss at step 8500: 1.855231 learning rate: 1.000000
# Minibatch perplexity: 5.99
# Validation set perplexity: 6.57
# Average loss at step 8600: 1.843345 learning rate: 1.000000
# Minibatch perplexity: 6.36
# Validation set perplexity: 6.58
# Average loss at step 8700: 1.837518 learning rate: 1.000000
# Minibatch perplexity: 6.22
# Validation set perplexity: 6.55
# Average loss at step 8800: 1.819737 learning rate: 1.000000
# Minibatch perplexity: 6.31
# Validation set perplexity: 6.51
# Average loss at step 8900: 1.831906 learning rate: 1.000000
# Minibatch perplexity: 5.70
# Validation set perplexity: 6.61
# Average loss at step 9000: 1.821774 learning rate: 1.000000
# Minibatch perplexity: 6.28
# ================================================================================
# azakast where systory forually sampetist to deccently engire facting and ght one
# kbtyn with attled hich euuhlen in the deasses a verlands in antamatious are sent
# wu declaasablian nharled form but mird titmon callout which defcaseptonal sposes
# iuniticil these conventre egerproced ezifurings the laws the he badficient and  e
#  monousland a fictions the orental one that and tafarepational afterrity years ac
# ================================================================================
# Validation set perplexity: 6.59
# Average loss at step 9100: 1.836292 learning rate: 1.000000
# Minibatch perplexity: 6.81
# Validation set perplexity: 6.56
# Average loss at step 9200: 1.867604 learning rate: 1.000000
# Minibatch perplexity: 6.50
# Validation set perplexity: 6.61
# Average loss at step 9300: 1.868110 learning rate: 1.000000
# Minibatch perplexity: 7.60
# Validation set perplexity: 6.59
# Average loss at step 9400: 1.858163 learning rate: 1.000000
# Minibatch perplexity: 6.70
# Validation set perplexity: 6.59
# Average loss at step 9500: 1.859494 learning rate: 1.000000
# Minibatch perplexity: 6.98
# Validation set perplexity: 6.59
# Average loss at step 9600: 1.847776 learning rate: 1.000000
# Minibatch perplexity: 6.03
# Validation set perplexity: 6.57
# Average loss at step 9700: 1.867517 learning rate: 1.000000
# Minibatch perplexity: 6.44
# Validation set perplexity: 6.62
# Average loss at step 9800: 1.861746 learning rate: 1.000000
# Minibatch perplexity: 6.72
# Validation set perplexity: 6.61
# Average loss at step 9900: 1.851581 learning rate: 1.000000
# Minibatch perplexity: 6.37
# Validation set perplexity: 6.57
# Average loss at step 10000: 1.870049 learning rate: 0.100000
# Minibatch perplexity: 6.81
# ================================================================================
# hzain and is but in the musew sechall one seven two include one six five three lu
# zmys chavh s zero bearl since at the a moncys the s use of lock the closcrity no
# xnnes aric callial leavire of bases of up gogrance pribus empended and cloyer and
# dx if rus javel caulit not a galtualihing that churstenlate on empersion in also
# qk to imagear my the ius with one nine nine cuulation prover from enametical supp
# ================================================================================
# Validation set perplexity: 6.57

# %% [markdown]
# ## Problem 3
# (difficult!)
#
# Write a sequence-to-sequence LSTM which mirrors all the words in a sentence. For example, if your input is:
#
# ```the quick brown fox```
#
# the model should attempt to output:
#
# ```eht kciuq nworb xof```
#
# Refer to the lecture on how to put together a sequence-to-sequence model, as well as [this article](http://arxiv.org/abs/1409.3215) for best practices.

# %%
num=10
train_data_t1 = list()
train_data_t2 = list()
for i in range(num + 1):
    train_data_t1.append(i)
    train_data_t2.append(i+1)

# %%
train_data_t[0:3]
# Out:
# [0, 1, 2]

# %%
inputs = zip(train_data_t1, train_data_t2)

# %%
# !pip install graphviz
# Out:
# Collecting graphviz
#   Downloading graphviz-0.8.1-py2.py3-none-any.whl
# Installing collected packages: graphviz
# Successfully installed graphviz-0.8.1

# %%
# TensorFlow Graph visualizer code
import numpy as np
from IPython.display import clear_output, Image, display, HTML

def strip_consts(graph_def, max_const_size=32):
    """Strip large constant values from graph_def."""
    strip_def = tf.GraphDef()
    for n0 in graph_def.node:
        n = strip_def.node.add() 
        n.MergeFrom(n0)
        if n.op == 'Const':
            tensor = n.attr['value'].tensor
            size = len(tensor.tensor_content)
            if size > max_const_size:
                tensor.tensor_content = "<stripped %d bytes>"%size
    return strip_def

def show_graph(graph_def, max_const_size=32):
    """Visualize TensorFlow graph."""
    if hasattr(graph_def, 'as_graph_def'):
        graph_def = graph_def.as_graph_def()
    strip_def = strip_consts(graph_def, max_const_size=max_const_size)
    code = """
        <script src="//cdnjs.cloudflare.com/ajax/libs/polymer/0.3.3/platform.js"></script>
        <script>
          function load() {{
            document.getElementById("{id}").pbtxt = {data};
          }}
        </script>
        <link rel="import" href="https://tensorboard.appspot.com/tf-graph-basic.build.html" onload=load()>
        <div style="height:600px">
          <tf-graph-basic id="{id}"></tf-graph-basic>
        </div>
    """.format(data=repr(str(strip_def)), id='graph'+str(np.random.rand()))

    iframe = """
        <iframe seamless style="width:1200px;height:620px;border:0" srcdoc="{}"></iframe>
    """.format(code.replace('"', '&quot;'))
    display(HTML(iframe))

# %%
show_graph(graph)
# Out:
#         <iframe seamless style="width:1200px;height:620px;border:0" srcdoc="
#         <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/polymer/0.3.3/platform.js&quot;></script>
#         <script>
#           function load() {
#             document.getElementById(&quot;graph0.0825722912972&quot;).pbtxt = 'node {\n  name: &quot;random_uniform/shape&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 2\n          }\n        }\n        tensor_content: &quot;\\331\\002\\000\\000\\200\\000\\000\\000&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;random_uniform/min&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: -1.0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;random_uniform/max&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 1.0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;random_uniform/RandomUniform&quot;\n  op: &quot;RandomUniform&quot;\n  input: &quot;random_uniform/shape&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;seed&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;seed2&quot;\n    value {\n      i: 0\n    }\n  }\n}\nnode {\n  name: &quot;random_uniform/sub&quot;\n  op: &quot;Sub&quot;\n  input: &quot;random_uniform/max&quot;\n  input: &quot;random_uniform/min&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;random_uniform/mul&quot;\n  op: &quot;Mul&quot;\n  input: &quot;random_uniform/RandomUniform&quot;\n  input: &quot;random_uniform/sub&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;random_uniform&quot;\n  op: &quot;Add&quot;\n  input: &quot;random_uniform/mul&quot;\n  input: &quot;random_uniform/min&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;Variable&quot;\n  op: &quot;VariableV2&quot;\n  attr {\n    key: &quot;container&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: 729\n        }\n        dim {\n          size: 128\n        }\n      }\n    }\n  }\n  attr {\n    key: &quot;shared_name&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n}\nnode {\n  name: &quot;Variable/Assign&quot;\n  op: &quot;Assign&quot;\n  input: &quot;Variable&quot;\n  input: &quot;random_uniform&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@Variable&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;use_locking&quot;\n    value {\n      b: true\n    }\n  }\n  attr {\n    key: &quot;validate_shape&quot;\n    value {\n      b: true\n    }\n  }\n}\nnode {\n  name: &quot;Variable/read&quot;\n  op: &quot;Identity&quot;\n  input: &quot;Variable&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@Variable&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;truncated_normal/shape&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n  ...
